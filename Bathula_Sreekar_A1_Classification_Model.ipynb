# %% [markdown]
# <table align="left" width=100%>
#             <div align="center">
#                 <font color="#21618C" size=16px>
#                   <b> Classification Model Development </b>
#                 </font>
#     </div>
# </table>
#
#
#
# <table align="left" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=6px>
#                   <b> Computational Data Analytics with Python </b>
#                 </font>
#     </div>
# </table>
#
#
#
#
# <table align="right">
#     <tr>
#         <td width="15%">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b><br>
#                         Name       : Sreekar Bathula<br>
#                         Student id : 28067764<br>
#                         Course     : Master's in Business Analytics<br>
#                         School     : Hult International Business School
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
#
#
# <table align="center" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=6px>
# <b> ___________________________________________________________________________________________________________ </b>
#                 </font>
#     </div>
# </table>
#
#
# <table align="left" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=26px>
#                     <b> CROSS SELL SUCCESS DATASET 2023 </u>
#                 </font>
#     </div>
# </table>

# %% [markdown]
# ## Basic Start

# %% [markdown]
# **Apprentice Chef, Inc. is an innovative company with a unique vision of home cooking to support the busy lifestyle of working professionals with healthy and delicious diet.**
#
# **Approach**
# 1) Understanding the data.
#
# 2) Cleaning the data.
#
# 3) Performing the exploratory data analysis.
#
# 4) Feature Engineering.
#
# 5) Modelling.
#
# **Understanding data:**
# In this step, I got familiar with the data which involves understanding the context and domain of the data, identifying variables and their types, checking for missing values, and discovering basic statistics such as mean, median, and mean values. standard deviation.
#
# **Data cleaning:**
# In this step, cleaning the data to remove any errors or inconsistencies that could affect the analysis. This also involved handling missing values, handling outliers and outliers, and removing duplicate or unrelated data.
#
# **Perform Exploratory Data Analysis (EDA):**
# In this step, I explore more data to better understand and understand the relationship between variables. It involves visualizing data using graphs and charts, calculating statistical measures such as correlations and distributions, and identifying patterns and trends in the data.
#
# **Technical features:**
# In this step, I converted the data to a format suitable for modeling. It involves selecting relevant features, transforming variables, and creating new variables or features that collect useful information from the data.
#
# **Modelling:**
# In this step, you need to create a predictive model that can generalize well to the new data. This involves choosing an appropriate algorithm, dividing the data into training and test sets, training the model on the training data, evaluating the model on the test data, and fine-tuning the parameters. of the model to optimize the performance of the model.

# %% [markdown]
# ## Importing libraries

# %%
# import 'Pandas' 
import pandas as pd 

# import 'Numpy' 
import numpy as np

# import subpackage of Matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# import 'Seaborn' 
import seaborn as sns

# to suppress warnings 
from warnings import filterwarnings
filterwarnings('ignore')

# display all columns of the dataframe
pd.options.display.max_columns = None

# display all rows of the dataframe
pd.options.display.max_rows = None
 
# to display the float values upto 6 decimal places     
pd.options.display.float_format = '{:.6f}'.format

# import train-test split 
from sklearn.model_selection import train_test_split

# import StandardScaler to perform scaling
from sklearn.preprocessing import StandardScaler 

# import various functions from sklearn
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split # train/test split
import sklearn.linear_model # linear modeling in scikit-learn 


# importing libraries
import pandas            as pd                       # data science essentials
import numpy             as np
import matplotlib.pyplot as plt                      # data visualization
import seaborn           as sns                      # enhanced data viz
import statsmodels.formula.api as smf                # statsmodel regressions
from sklearn.model_selection import train_test_split # train-test split
from sklearn.linear_model import LogisticRegression  # logistic regression
from sklearn.metrics import confusion_matrix         # confusion matrix
from sklearn.metrics import roc_auc_score            # auc score
from sklearn.neighbors import KNeighborsClassifier   # KNN for classification
from sklearn.neighbors import KNeighborsRegressor    # KNN for regression
from sklearn.preprocessing import StandardScaler     # standard scaler
from sklearn.model_selection import GridSearchCV     # hyperparameter tuning
from sklearn.metrics import make_scorer              # customizable scorer
from sklearn.ensemble import RandomForestClassifier     # random forest
from sklearn.ensemble import GradientBoostingClassifier # gbm

# CART model packages
from sklearn.tree import DecisionTreeClassifier      # classification trees
from sklearn.tree import export_graphviz             # exports graphics
#from sklearn.externals.six import StringIO           # saves objects in memory
from IPython.display import Image                    # displays on frontend
#import pydotplus                                     # interprets dot objects

# to suppress warnings 
from warnings import filterwarnings
filterwarnings('ignore')
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# ## Importing data from excel

# %%
#Reading the data from excel

# specifying the path and file name
file = 'Cross_Sell_Success_Dataset_2023.xlsx'

# reading the file into Python
data=pd.read_excel(file)

# checking the file and displaying the first 5 rows
data.head(n = 5)
# Out:
#    CROSS_SELL_SUCCESS                             EMAIL     REVENUE  \
# 0                   1       steffon.baratheon@yahoo.com 4920.000000
# 1                   0           harlon.greyjoy@visa.com 6150.000000
# 2                   0            monster@protonmail.com 3435.000000
# 3                   1  damon.lannister.(lord)@yahoo.com 3330.000000
# 4                   1        raynald.westerling@jnj.com 3427.500000
#
#    TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  CONTACTS_W_CUSTOMER_SERVICE  \
# 0                  493                   9                            1
# 1                  361                   9                            1
# 2                  278                   6                            1
# 3                  269                   8                            1
# 4                  276                   7                            1
#
#    PRODUCT_CATEGORIES_VIEWED  AVG_TIME_PER_SITE_VISIT  \
# 0                         10               265.600000
# ...

# %% [markdown]
# **Data Description - The variables of the dataset contains Cross sell success, Revenue, Email_id, Total meals ordered, Unique meals purchased, contacts to customer services, product categories viewed, Average time per site, Cancellation afternoon, PC logins,Mobile logins, Weekly plan, Late delivery, Average Preparation video time, Largest Order size, Average mean rating, Total photos viewed.**

# %% [markdown]
# # Understanding the data

# %% [markdown]
# ## Obtaining the shape of data set

# %%
# formatting and printing the dimensions of the dataset
print(f"""
Size of Original Dataset
------------------------
Observations: {data.shape[0]}
Features:     {data.shape[1]}
""")
# Out:
# Size of Original Dataset
# ------------------------
# Observations: 1946
# Features:     17

# %% [markdown]
# **From the above dimensional table we confirm that there are 17 column and 1946 rows of data.**

# %% [markdown]
# ## Checking the columns, Number of null values, Data types

# %%
# INFOrmation about each variable
data.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CROSS_SELL_SUCCESS           1946 non-null   int64
#  1   EMAIL                        1946 non-null   object
#  2   REVENUE                      1946 non-null   float64
#  3   TOTAL_MEALS_ORDERED          1946 non-null   int64
#  4   UNIQUE_MEALS_PURCH           1946 non-null   int64
#  5   CONTACTS_W_CUSTOMER_SERVICE  1946 non-null   int64
#  6   PRODUCT_CATEGORIES_VIEWED    1946 non-null   int64
#  7   AVG_TIME_PER_SITE_VISIT      1946 non-null   float64
#  8   CANCELLATIONS_AFTER_NOON     1946 non-null   int64
#  9   PC_LOGINS                    1946 non-null   int64
#  10  MOBILE_LOGINS                1946 non-null   int64
#  11  WEEKLY_PLAN                  1946 non-null   int64
#  12  LATE_DELIVERIES              1946 non-null   int64
# ...

# %% [markdown]
# **From the above information table, I found that there are no null values in the data set.**

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# ## CORRECTING COLUMN NAMES

# %%
# Renaming the columnn name Late_deliveries as it is mis-spelled
data=data.rename(columns={'LARGEST_ORDER_SIZE':'AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'})
data=data.rename(columns={'LATE_DELIVERIES ':'LATE_DELIVERIES'})
data.head(2)
# Out:
#    CROSS_SELL_SUCCESS                        EMAIL     REVENUE  \
# 0                   1  steffon.baratheon@yahoo.com 4920.000000
# 1                   0      harlon.greyjoy@visa.com 6150.000000
#
#    TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  CONTACTS_W_CUSTOMER_SERVICE  \
# 0                  493                   9                            1
# 1                  361                   9                            1
#
#    PRODUCT_CATEGORIES_VIEWED  AVG_TIME_PER_SITE_VISIT  \
# 0                         10               265.600000
# 1                          6               247.000000
#
#    CANCELLATIONS_AFTER_NOON  PC_LOGINS  MOBILE_LOGINS  WEEKLY_PLAN  \
# 0                         5          5              2            0
# 1                         2          5              1            0
#
#    LATE_DELIVERIES  AVG_PREP_VID_TIME  AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER  \
# 0                0         137.410000                                     6
# ...

# %% [markdown]
# **Correcting the column names a) Largest Order size to AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER b) There is an extra gap in the Late_deliveries column.**

# %% [markdown]
# ## Outlier Treatment

# %%
#Making the new features by logarithmic transformation of data.
data['LOG_TOTAL_MEALS_ORDERED']=np.log(data['TOTAL_MEALS_ORDERED']) #Log of TOTAL_MEALS_ORDERED
data['LOG_UNIQUE_MEALS_PURCH']=np.log(data['UNIQUE_MEALS_PURCH']) #Log of UNIQUE_MEALS_PURCH
data['LOG_CONTACTS_W_CUSTOMER_SERVICE']=np.log(data['CONTACTS_W_CUSTOMER_SERVICE']) #Log of CONTACTS_W_CUSTOMER_SERVICE
data['LOG_PRODUCT_CATEGORIES_VIEWED']=np.log(data['PRODUCT_CATEGORIES_VIEWED'])#Log of PRODUCT_CATEGORIES_VIEWED
data['LOG_AVG_TIME_PER_SITE_VISIT']=np.log(data['AVG_TIME_PER_SITE_VISIT']) #Log of AVG_TIME_PER_SITE_VISIT
data['LOG_CANCELLATIONS_AFTER_NOON']=np.log(data['CANCELLATIONS_AFTER_NOON']+0.001)#Log of CANCELLATIONS_AFTER_NOON
data['LOG_LATE_DELIVERIES']=np.log(data['LATE_DELIVERIES']+0.001)#Log of LATE_DELIVERIES
data['LOG_AVG_PREP_VID_TIME']=np.log(data['AVG_PREP_VID_TIME']) #Log of AVG_PREP_VID_TIME
data['LOG_AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER']=np.log(data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'])#Log of LARGEST_ORDER_SIZE
data['LOG_AVG_MEAN_RATING']=np.log(data['AVG_MEAN_RATING']) #Log of AVG_MEAN_RATING
data['LOG_REVENUE']=np.log(data['REVENUE']) #Log of revenue

# %% [markdown]
# **Appling the log to the features present to reduce the outliers.**

# %% [markdown]
# # Exploratory data analysis

# %%
data.describe()
# Out:
#        CROSS_SELL_SUCCESS     REVENUE  TOTAL_MEALS_ORDERED  \
# count         1946.000000 1946.000000          1946.000000
# mean             0.678828 2107.292652            74.634121
# std              0.467047 1138.290709            55.309782
# min              0.000000  131.000000            11.000000
# 25%              0.000000 1350.000000            39.000000
# 50%              1.000000 1740.000000            60.000000
# 75%              1.000000 2670.000000            95.000000
# max              1.000000 8793.750000           493.000000
#
#        UNIQUE_MEALS_PURCH  CONTACTS_W_CUSTOMER_SERVICE  \
# count         1946.000000                  1946.000000
# mean             6.983556                     4.904933
# std              2.281193                     2.502175
# min              1.000000                     1.000000
# 25%              5.000000                     3.000000
# 50%              7.000000                     5.000000
# ...

# %% [markdown]
# **Statistical Analysis**

# %%
data.corr()
# Out:
#                                           CROSS_SELL_SUCCESS   REVENUE  \
# CROSS_SELL_SUCCESS                                  1.000000  0.004540
# REVENUE                                             0.004540  1.000000
# TOTAL_MEALS_ORDERED                                 0.006475  0.600489
# UNIQUE_MEALS_PURCH                                  0.036541  0.101659
# CONTACTS_W_CUSTOMER_SERVICE                        -0.000183  0.174303
# PRODUCT_CATEGORIES_VIEWED                           0.004671  0.034492
# AVG_TIME_PER_SITE_VISIT                             0.032115  0.643580
# CANCELLATIONS_AFTER_NOON                            0.142681  0.003420
# PC_LOGINS                                           0.044462  0.016118
# MOBILE_LOGINS                                       0.062023  0.073381
# WEEKLY_PLAN                                        -0.005337  0.009794
# LATE_DELIVERIES                                     0.023941 -0.020114
# ...

# %% [markdown]
# **Checked the correlation for the feature - There is very less correlation for our features with the target variable. So, we have to perform feature engineering**

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Categorical variable

# %% [markdown]
# **Splitting the email id's based on the data as professional, Personal, Junk**

# %%
# define function to categorize domains
def categorize_domain(domain):
    personal_domains = ['gmail.com', 'yahoo.com', 'protonmail.com']
    junk_domains = ['me.com', 'aol.com', 'hotmail.com', 'live.com', 'msn.com', 'passport.com']
    if domain in personal_domains:
        return 'PERSONAL'
    elif domain in junk_domains:
        return 'JUNK'
    else: 
        return 'PROFESSIONAL'

# extract domain name from email addresses
data['SS_EMAIL_CATEGORY'] = data['EMAIL'].apply(lambda x: x.split('@')[1])

# apply domain categorization function
data['SS_EMAIL_CATEGORY'] = data['SS_EMAIL_CATEGORY'].apply(categorize_domain)

# print result
data.head()
# Out:
#    CROSS_SELL_SUCCESS                             EMAIL     REVENUE  \
# 0                   1       steffon.baratheon@yahoo.com 4920.000000
# 1                   0           harlon.greyjoy@visa.com 6150.000000
# 2                   0            monster@protonmail.com 3435.000000
# 3                   1  damon.lannister.(lord)@yahoo.com 3330.000000
# 4                   1        raynald.westerling@jnj.com 3427.500000
#
#    TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  CONTACTS_W_CUSTOMER_SERVICE  \
# 0                  493                   9                            1
# 1                  361                   9                            1
# 2                  278                   6                            1
# 3                  269                   8                            1
# 4                  276                   7                            1
#
#    PRODUCT_CATEGORIES_VIEWED  AVG_TIME_PER_SITE_VISIT  \
# 0                         10               265.600000
# ...

# %% [markdown]
# **Converting the Categorical variable to Numerical Variable**

# %%
encoded_data = pd.get_dummies(data['SS_EMAIL_CATEGORY'], prefix='SS_EMAIL_CATEGORY',drop_first=True)

# Add the one-hot encoded columns to the original DataFrame
data = pd.concat([data, encoded_data], axis=1)
data.head(2)
# Out:
#    CROSS_SELL_SUCCESS                        EMAIL     REVENUE  \
# 0                   1  steffon.baratheon@yahoo.com 4920.000000
# 1                   0      harlon.greyjoy@visa.com 6150.000000
#
#    TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  CONTACTS_W_CUSTOMER_SERVICE  \
# 0                  493                   9                            1
# 1                  361                   9                            1
#
#    PRODUCT_CATEGORIES_VIEWED  AVG_TIME_PER_SITE_VISIT  \
# 0                         10               265.600000
# 1                          6               247.000000
#
#    CANCELLATIONS_AFTER_NOON  PC_LOGINS  MOBILE_LOGINS  WEEKLY_PLAN  \
# 0                         5          5              2            0
# 1                         2          5              1            0
#
#    LATE_DELIVERIES  AVG_PREP_VID_TIME  AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER  \
# 0                0         137.410000                                     6
# ...

# %% [markdown]
# ## Numerical Data

# %%
#Revenue per total meal ordered.
data['FE_REVENUE_PER_MEAL'] = data['REVENUE']/data['TOTAL_MEALS_ORDERED']
#Revenue per login.
data['FE_REVENUE_PER_LOGIN']= data['REVENUE']/(data['PC_LOGINS']+data['MOBILE_LOGINS'])
#Unique meal purch per total meals ordered
data['FE_UNIQUE_MEAL_ORDERED_PER_TOTAL_ORDERED']=data['UNIQUE_MEALS_PURCH']/data['TOTAL_MEALS_ORDERED']
#Total photo viewed per avg time per site visit
data['FE_PHOTOS_VIEWED_PER_AVG_TIME_SPENT']=data['TOTAL_PHOTOS_VIEWED']/data['AVG_TIME_PER_SITE_VISIT']
#Avg num of meal ordered per customer per total meal ordered
data['FE_AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER']=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER']/data['TOTAL_MEALS_ORDERED']
#generating feature as ratio of service requests per meal ordered
data['FE_CONTACTS_W_CUSTOMER_SERVICE'] =  data['TOTAL_MEALS_ORDERED'] / data['CONTACTS_W_CUSTOMER_SERVICE']
#cancellation after noon per meal ordered
data['FE_CANCELLATION_AFTER_NOON_PMO'] = data['CANCELLATIONS_AFTER_NOON'] / data['TOTAL_MEALS_ORDERED']

# %% [markdown]
# **Checking the correlation**

# %%
data.corr()
# Out:
#                                           CROSS_SELL_SUCCESS   REVENUE  \
# CROSS_SELL_SUCCESS                                  1.000000  0.004540
# REVENUE                                             0.004540  1.000000
# TOTAL_MEALS_ORDERED                                 0.006475  0.600489
# UNIQUE_MEALS_PURCH                                  0.036541  0.101659
# CONTACTS_W_CUSTOMER_SERVICE                        -0.000183  0.174303
# PRODUCT_CATEGORIES_VIEWED                           0.004671  0.034492
# AVG_TIME_PER_SITE_VISIT                             0.032115  0.643580
# CANCELLATIONS_AFTER_NOON                            0.142681  0.003420
# PC_LOGINS                                           0.044462  0.016118
# MOBILE_LOGINS                                       0.062023  0.073381
# WEEKLY_PLAN                                        -0.005337  0.009794
# LATE_DELIVERIES                                     0.023941 -0.020114
# ...

# %%
data.columns
# Out:
# Index(['CROSS_SELL_SUCCESS', 'EMAIL', 'REVENUE', 'TOTAL_MEALS_ORDERED',
#        'UNIQUE_MEALS_PURCH', 'CONTACTS_W_CUSTOMER_SERVICE',
#        'PRODUCT_CATEGORIES_VIEWED', 'AVG_TIME_PER_SITE_VISIT',
#        'CANCELLATIONS_AFTER_NOON', 'PC_LOGINS', 'MOBILE_LOGINS', 'WEEKLY_PLAN',
#        'LATE_DELIVERIES', 'AVG_PREP_VID_TIME',
#        'AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER', 'AVG_MEAN_RATING',
#        'TOTAL_PHOTOS_VIEWED', 'LOG_TOTAL_MEALS_ORDERED',
#        'LOG_UNIQUE_MEALS_PURCH', 'LOG_CONTACTS_W_CUSTOMER_SERVICE',
#        'LOG_PRODUCT_CATEGORIES_VIEWED', 'LOG_AVG_TIME_PER_SITE_VISIT',
#        'LOG_CANCELLATIONS_AFTER_NOON', 'LOG_LATE_DELIVERIES',
#        'LOG_AVG_PREP_VID_TIME', 'LOG_AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER',
#        'LOG_AVG_MEAN_RATING', 'LOG_REVENUE', 'SS_EMAIL_CATEGORY',
#        'SS_EMAIL_CATEGORY_PERSONAL', 'SS_EMAIL_CATEGORY_PROFESSIONAL',
#        'FE_REVENUE_PER_MEAL', 'FE_REVENUE_PER_LOGIN',
#        'FE_UNIQUE_MEAL_ORDERED_PER_TOTAL_ORDERED',
# ...

# %% [markdown]
# # Model Development - Classification Model

# %% [markdown]
# **Making x_variable**

# %%
variables_dict = { "Base" : [   # dataset without feature engineering
        'REVENUE', 'TOTAL_MEALS_ORDERED', 'UNIQUE_MEALS_PURCH',
        'CONTACTS_W_CUSTOMER_SERVICE',    'PRODUCT_CATEGORIES_VIEWED', 
        'AVG_TIME_PER_SITE_VISIT', 
        'CANCELLATIONS_AFTER_NOON',  'PC_LOGINS',
        'MOBILE_LOGINS', 'WEEKLY_PLAN', 'LATE_DELIVERIES', 
        'AVG_PREP_VID_TIME', 'AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER',  
        'AVG_MEAN_RATING', 'TOTAL_PHOTOS_VIEWED','SS_EMAIL_CATEGORY_PERSONAL', 
        'SS_EMAIL_CATEGORY_PROFESSIONAL'],
                  
                  "Full_Model" :  [ 'REVENUE', 
                      'TOTAL_MEALS_ORDERED', 
                      'UNIQUE_MEALS_PURCH', 
                      'CONTACTS_W_CUSTOMER_SERVICE', 
                      'PRODUCT_CATEGORIES_VIEWED', 
                      'AVG_TIME_PER_SITE_VISIT', 
                      'CANCELLATIONS_AFTER_NOON', 
                      'PC_LOGINS', 
                      'MOBILE_LOGINS', 
                      'WEEKLY_PLAN', 
                      'LATE_DELIVERIES',
                      'AVG_PREP_VID_TIME', 
                      'AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER', 
                      'AVG_MEAN_RATING',
                      'TOTAL_PHOTOS_VIEWED',
                      'LOG_TOTAL_MEALS_ORDERED',
                      'LOG_UNIQUE_MEALS_PURCH', 
                      'LOG_CONTACTS_W_CUSTOMER_SERVICE', 
                      'LOG_PRODUCT_CATEGORIES_VIEWED',
                      'LOG_AVG_TIME_PER_SITE_VISIT',
                      'LOG_CANCELLATIONS_AFTER_NOON',
                      'LOG_LATE_DELIVERIES',
                      'LOG_AVG_PREP_VID_TIME',
                      'LOG_AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER',
                      'LOG_AVG_MEAN_RATING', 
                      'LOG_REVENUE', 
                      'SS_EMAIL_CATEGORY_PERSONAL', 
                      'SS_EMAIL_CATEGORY_PROFESSIONAL',  
                      'FE_UNIQUE_MEAL_ORDERED_PER_TOTAL_ORDERED', 
                      'FE_PHOTOS_VIEWED_PER_AVG_TIME_SPENT', 
                      'FE_AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER', 
                      'FE_CONTACTS_W_CUSTOMER_SERVICE', 
                      'FE_CANCELLATION_AFTER_NOON_PMO'],
                  
                  "Important_Model"  : [   # variables from EDA
          'LOG_TOTAL_MEALS_ORDERED',
                      'LOG_UNIQUE_MEALS_PURCH', 
                      'LOG_CONTACTS_W_CUSTOMER_SERVICE', 
                      'LOG_AVG_TIME_PER_SITE_VISIT',
                      'LOG_CANCELLATIONS_AFTER_NOON',
                      'LOG_LATE_DELIVERIES',
                      'LOG_AVG_PREP_VID_TIME',
                      'LOG_AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER', 
                      'LOG_REVENUE', 
                      'SS_EMAIL_CATEGORY_PERSONAL', 
                      'SS_EMAIL_CATEGORY_PROFESSIONAL', 
                      'FE_REVENUE_PER_MEAL',
                      'FE_REVENUE_PER_LOGIN', 
                      'FE_UNIQUE_MEAL_ORDERED_PER_TOTAL_ORDERED', 
                      'FE_PHOTOS_VIEWED_PER_AVG_TIME_SPENT', 
                      'FE_AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER', 
                      'FE_CONTACTS_W_CUSTOMER_SERVICE', 
                      'FE_CANCELLATION_AFTER_NOON_PMO'
    ],
                 "target"     : [    # target variable
        'CROSS_SELL_SUCCESS'
    ]
                 }


# Saving model scores
# creating an empty list
model_performance = [['Model', 'Training Accuracy',
                      'Testing Accuracy', 'AUC Value']]

# setting random state
seed = 219

# Defining target variable
data_target = data.loc[: , variables_dict['target']]

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ###  Base model

# %%
###### Non Standardized Preparation 
# Defining explanatory variables (add according to new feature selections)
Base_data = data.loc[: , variables_dict['Base']]
# setting up train-test split
x_train, x_test, y_train, y_test = train_test_split(
            Base_data, # x-variables (can change this)
            data_target, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219,
             stratify     = data_target)

# merging training data for statsmodels
data_train = pd.concat([x_train, y_train], axis = 1) # contains target variable!


# INSTANTIATING a logistic regression model
logreg = LogisticRegression(random_state = 219)

# FITTING the training data
logreg_fit = logreg.fit(x_train, y_train.values.reshape(-1,))


# PREDICTING based on the testing set
logreg_pred = logreg_fit.predict(x_test)

# train accuracy
logreg_train_acc  = logreg_fit.score(x_train, y_train).round(4)

# test accuracy
logreg_test_acc   = logreg_fit.score(x_test, y_test).round(4)

# auc value
logreg_auc = roc_auc_score(y_true  = y_test,
                           y_score = logreg_pred).round(4)

print('Logistic Regression with Base model')
print('Training ACCURACY:', logreg_train_acc)
print('Testing  ACCURACY:', logreg_test_acc)
print('AUC Score        :', logreg_auc)
# Out:
# Logistic Regression with Base model
# Training ACCURACY: 0.6779
# Testing  ACCURACY: 0.6776
# AUC Score        : 0.4985

# %% [markdown]
# **Here AUC is less than 0.5**

# %% [markdown]
# ### FULL MODEL

# %%
###### Non Standardized Preparation 
# Defining explanatory variables (add according to new feature selections)
data_Full_Model = data.loc[: , variables_dict['Full_Model']]
# setting up train-test split
x_train, x_test, y_train, y_test = train_test_split(
            data_Full_Model, # x-variables (can change this)
            data_target, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219,
            stratify     = data_target)

# merging training data for statsmodels
data_train = pd.concat([x_train, y_train], axis = 1) # contains target variable!


# INSTANTIATING a logistic regression model
logreg = LogisticRegression(random_state = 219)

# FITTING the training data
logreg_fit = logreg.fit(x_train, y_train.values.reshape(-1,))


# PREDICTING based on the testing set
logreg_pred = logreg_fit.predict(x_test)

# train accuracy
logreg_train_acc  = logreg_fit.score(x_train, y_train).round(4)

# test accuracy
logreg_test_acc   = logreg_fit.score(x_test, y_test).round(4)

# auc value
logreg_auc = roc_auc_score(y_true  = y_test,
                           y_score = logreg_pred).round(4)

print('Training ACCURACY:', logreg_train_acc)
print('Testing  ACCURACY:', logreg_test_acc)
print('AUC Score        :', logreg_auc)
# Out:
# Training ACCURACY: 0.6779
# Testing  ACCURACY: 0.6776
# AUC Score        : 0.4985

# %% [markdown]
# **Here AUC Score is less than 0.5**

# %% [markdown]
# ### Important Model

# %%
###### Non Standardized Preparation 
# Defining explanatory variables (add according to new feature selections)
data_Important_Model = data.loc[: , variables_dict['Important_Model']]
# setting up train-test split
x_train, x_test, y_train, y_test = train_test_split(
            data_Important_Model, # x-variables (can change this)
            data_target, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219,
            stratify     = data_target)

# merging training data for statsmodels
data_train = pd.concat([x_train, y_train], axis = 1) # contains target variable!


# INSTANTIATING a logistic regression model
logreg = LogisticRegression(random_state = 219)

# FITTING the training data
logreg_fit = logreg.fit(x_train, y_train.values.reshape(-1,))


# PREDICTING based on the testing set
logreg_pred = logreg_fit.predict(x_test)

# train accuracy
logreg_train_acc  = logreg_fit.score(x_train, y_train).round(4)

# test accuracy
logreg_test_acc   = logreg_fit.score(x_test, y_test).round(4)

# auc value
logreg_auc = roc_auc_score(y_true  = y_test,
                           y_score = logreg_pred).round(4)

print('Training ACCURACY:', logreg_train_acc)
print('Testing  ACCURACY:', logreg_test_acc)
print('AUC Score        :', logreg_auc)
# Out:
# Training ACCURACY: 0.7121
# Testing  ACCURACY: 0.694
# AUC Score        : 0.5801

# %% [markdown]
# **Using the Important model we got the good AUC score which is 0.58**

# %% [markdown]
# ### HyperTuning

# %%
'''
##########################################
### GridSearchCV
##########################################
## declaring a hyperparameter space
solver_space     = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'] # use L2 penalty
C_space          = pd.np.arange(0.1, 3.0, 0.1)

warm_start_space = [True, False]

## creating a hyperparameter grid
param_grid = {'C'            : C_space,          
           'warm_start'   : warm_start_space,
            'solver'       : solver_space
          } 
#

## INSTANTIATING the model object without hyperparameters
lr_tuned = LogisticRegression(max_iter = 1000,
                             random_state = seed)


## GridSearchCV object
lr_tuned_cv = GridSearchCV(estimator  = lr_tuned, 
                           param_grid = param_grid, 
                           cv         = 3, 
                           scoring    = make_scorer(roc_auc_score,
                                                   needs_threshold = False))


## FITTING to the FULL DATASET (due to cross-validation)
lr_tuned_cv.fit(data_Important_Model, data_target.values.reshape(-1,))


## printing the optimal parameters and best score
print("Tuned Parameters  :", lr_tuned_cv.best_params_)
print("Tuned CV AUC      :", lr_tuned_cv.best_score_.round(4))
'''
# Out:
# '\n##########################################\n### GridSearchCV\n##########################################\n## declaring a hyperparameter space\nsolver_space     = [\'newton-cg\', \'lbfgs\', \'liblinear\', \'sag\', \'saga\'] # use L2 penalty\nC_space          = pd.np.arange(0.1, 3.0, 0.1)\n\nwarm_start_space = [True, False]\n\n## creating a hyperparameter grid\nparam_grid = {\'C\'            : C_space,          \n           \'warm_start\'   : warm_start_space,\n            \'solver\'       : solver_space\n          } \n#\n\n## INSTANTIATING the model object without hyperparameters\nlr_tuned = LogisticRegression(max_iter = 1000,\n                             random_state = seed)\n\n\n## GridSearchCV object\nlr_tuned_cv = GridSearchCV(estimator  = lr_tuned, \n                           param_grid = param_grid, \n                           cv         = 3, \n                           scoring    = make_scorer(roc_auc_score,\n                                                   needs_thres
# ...

# %% [markdown]
# ### Tuned Parameters

# %%
# Model with Tuned Parameters
# INSTANTIATING a logistic regression model
logreg_tuned = LogisticRegression(solver = 'newton-cg',
                                  C = 2.9,
                                  max_iter = 1500,
                                  warm_start = True) 

# FITTING the training data
logreg_fit_tuned = logreg_tuned.fit(x_train, y_train.values.reshape(-1,)) # removes warning on column shap

# PREDICTING based on the testing set
logreg_pred_tuned = logreg_fit_tuned.predict(x_test)

# train accuracy
logreg_train_acc_tuned  = logreg_fit_tuned.score(x_train, y_train).round(4)

# test accuracy
logreg_test_acc_tuned   = logreg_fit_tuned.score(x_test, y_test).round(4)

# auc value
logreg_auc_tuned = roc_auc_score(y_true  = y_test,
                                y_score = logreg_pred_tuned).round(4)

print('Training ACCURACY:', logreg_train_acc_tuned)
print('Testing  ACCURACY:', logreg_test_acc_tuned)
print('AUC Score        :', logreg_auc_tuned)
# Out:
# Training ACCURACY: 0.7162
# Testing  ACCURACY: 0.7105
# AUC Score        : 0.6074

# %% [markdown]
# **By tuning, we got the good AUC score i.e 0.6074**

# %% [markdown]
# **Making a confusion matrix**

# %%
# compute confusion matrix
conf_mat = confusion_matrix(y_test, logreg_pred_tuned)

# print confusion matrix
print('Confusion matrix:\n', conf_mat)
# Out:
# Confusion matrix:
#  [[ 50 106]
#  [ 35 296]]

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### Base model

# %%
####### Non Standardized Preparation 
## Defining explanatory variables (add according to new feature selections)
data_full = data.loc[: , variables_dict['Base']]

## train-test split with stratification
x_train, x_test, y_train, y_test = train_test_split(
           data_full,  # change
            data_target,
           test_size = 0.25,
            random_state = 219,
            stratify = data_target) # stratifying target variable to ensure balance

## merging training data for statsmodels
chef_train = pd.concat([x_train, y_train], axis = 1) # contains target variable!
#
## INSTANTIATING a classification tree object
full_tree = DecisionTreeClassifier(random_state = seed)
#
## FITTING the training data
full_tree_fit = full_tree.fit(x_train, y_train.values.reshape(-1,))
#
## PREDICTING on new data
full_tree_pred = full_tree_fit.predict(x_test)
#
full_tree_train_acc = full_tree_fit.score(x_train, y_train).round(4)
#
full_tree_test_acc = full_tree_fit.score(x_test, y_test).round(4)
#
full_tree_auc = roc_auc_score(y_true  = y_test, y_score = full_tree_pred).round(4)
#
## SCORING the model
print('Training ACCURACY:', full_tree_fit.score(x_train, y_train).round(4))
print('Testing  ACCURACY:', full_tree_fit.score(x_test, y_test).round(4))
print('AUC Score        :', roc_auc_score(y_true  = y_test,
                                       y_score = full_tree_pred).round(4))
# Out:
# Training ACCURACY: 1.0
# Testing  ACCURACY: 0.5975
# AUC Score        : 0.5429

# %% [markdown]
# **Here we got a good AUC score >0.54**

# %% [markdown]
# ### Full Model

# %%
####### Non Standardized Preparation 
## Defining explanatory variables (add according to new feature selections)
data_base = data.loc[: , variables_dict['Full_Model']]

## train-test split with stratification
x_train, x_test, y_train, y_test = train_test_split(
           data_base,  # change
            data_target,
           test_size = 0.25,
            random_state = seed,
            stratify = data_target) # stratifying target variable to ensure balance

## merging training data for statsmodels
chef_train = pd.concat([x_train, y_train], axis = 1) # contains target variable!
#
## INSTANTIATING a classification tree object
full_tree = DecisionTreeClassifier(random_state = seed)
#
## FITTING the training data
full_tree_fit = full_tree.fit(x_train, y_train.values.reshape(-1,))
#
## PREDICTING on new data
full_tree_pred = full_tree_fit.predict(x_test)
#
full_tree_train_acc = full_tree_fit.score(x_train, y_train).round(4)
#
full_tree_test_acc = full_tree_fit.score(x_test, y_test).round(4)
#
full_tree_auc = roc_auc_score(y_true  = y_test, y_score = full_tree_pred).round(4)
#
## SCORING the model
print('Training ACCURACY:', full_tree_fit.score(x_train, y_train).round(4))
print('Testing  ACCURACY:', full_tree_fit.score(x_test, y_test).round(4))
print('AUC Score        :', roc_auc_score(y_true  = y_test,
                                       y_score = full_tree_pred).round(4))
# Out:
# Training ACCURACY: 1.0
# Testing  ACCURACY: 0.6181
# AUC Score        : 0.553

# %% [markdown]
# **Here also we got good AUC Score >0.55**

# %% [markdown]
# ### Important Model

# %%
####### Non Standardized Preparation 
## Defining explanatory variables (add according to new feature selections)
data_base = data.loc[: , variables_dict['Important_Model']]

## train-test split with stratification
x_train, x_test, y_train, y_test = train_test_split(
           data_base,  # change
            data_target,
           test_size = 0.25,
            random_state = 219,
            stratify = data_target) # stratifying target variable to ensure balance

## merging training data for statsmodels
chef_train = pd.concat([x_train, y_train], axis = 1) # contains target variable!
#
## INSTANTIATING a classification tree object
full_tree = DecisionTreeClassifier(random_state = 219)
#
## FITTING the training data
full_tree_fit = full_tree.fit(x_train, y_train.values.reshape(-1,))
#
## PREDICTING on new data
full_tree_pred = full_tree_fit.predict(x_test)
#
full_tree_train_acc = full_tree_fit.score(x_train, y_train).round(4)
#
full_tree_test_acc = full_tree_fit.score(x_test, y_test).round(4)
#
full_tree_auc = roc_auc_score(y_true  = y_test, y_score = full_tree_pred).round(4)
#
## SCORING the model
print('Training ACCURACY:', full_tree_fit.score(x_train, y_train).round(4))
print('Testing  ACCURACY:', full_tree_fit.score(x_test, y_test).round(4))
print('AUC Score        :', roc_auc_score(y_true  = y_test,
                                       y_score = full_tree_pred).round(4))
# Out:
# Training ACCURACY: 1.0
# Testing  ACCURACY: 0.6201
# AUC Score        : 0.5731

# %% [markdown]
# **Here we got good AUC score greater than 0.57**

# %% [markdown]
# ### Hypertuning

# %%
'''
################
#Randomized Search cv
###################

#defining hyperparameterspace
criterion = ['gini', 'entropy']
splitter = ['best', 'random']
max_depth = np.arange(1, 8, 1)
samples_leaf = np.arange(1, 50, 1)
min_sample_split = np.arange(2, 20, 1)

#creating hyperparameter grid
param_grid = {'criterion'  : criterion,
              'splitter'   : splitter,
              'max_depth'  : max_depth,
              'min_samples_leaf' : samples_leaf,
             'min_samples_split' : min_sample_split}

#INSTANTIATING Tree
tuned_tree = DecisionTreeClassifier(random_state = 219)

#RandomizedSearchcv
tuned_tree_cv = RandomizedSearchCV(estimator          = tuned_tree,
                                  param_distributions = param_grid,
                                  cv                  = 3,
                                  n_iter              = 2000,
                                  random_state        = 219,
                                  scoring = make_scorer(roc_auc_score,
                                             needs_threshold = False))
#Fitting the model on full dataset
tuned_tree_cv.fit(data_base, data_target)

#PREDICT is not required


# printing the optimal parameters and best score
print("Tuned Parameters  :", tuned_tree_cv.best_params_)
print("Tuned Training AUC:", tuned_tree_cv.best_score_.round(4))
'''
# Out:
# '\n################\n#Randomized Search cv\n###################\n\n#defining hyperparameterspace\ncriterion = [\'gini\', \'entropy\']\nsplitter = [\'best\', \'random\']\nmax_depth = np.arange(1, 8, 1)\nsamples_leaf = np.arange(1, 50, 1)\nmin_sample_split = np.arange(2, 20, 1)\n\n#creating hyperparameter grid\nparam_grid = {\'criterion\'  : criterion,\n              \'splitter\'   : splitter,\n              \'max_depth\'  : max_depth,\n              \'min_samples_leaf\' : samples_leaf,\n             \'min_samples_split\' : min_sample_split}\n\n#INSTANTIATING Tree\ntuned_tree = DecisionTreeClassifier(random_state = 219)\n\n#RandomizedSearchcv\ntuned_tree_cv = RandomizedSearchCV(estimator          = tuned_tree,\n                                  param_distributions = param_grid,\n                                  cv                  = 3,\n                                  n_iter              = 2000,\n                                  random_state        = 219,\n                         
# ...

# %% [markdown]
# ### Tuning Parameter

# %%
tree_tuned = DecisionTreeClassifier(criterion='entropy',
                                    max_depth=2,
                                    min_samples_leaf=14, min_samples_split=19, 
                                    random_state=219, splitter='best')


# FITTING to the FULL DATASET (due to cross-validation from GridSearch)
tree_tuned_fit = tree_tuned.fit(data_base, data_target)

# PREDICTING based on the testing set
tree_tuned_pred = tree_tuned.predict(x_test)

# SCORING the results
print('Training ACCURACY:', tree_tuned.score(x_train, y_train).round(4))
print('Testing  ACCURACY:', tree_tuned.score(x_test, y_test).round(4))
print('AUC Score        :', roc_auc_score(y_true  = y_test,
                                          y_score = tree_tuned_pred).round(4))

model= "Tuned Classification Tree"
a= tree_tuned.score(x_train, y_train).round(4)
b= tree_tuned.score(x_test, y_test).round(4)
c=roc_auc_score(y_true  = y_test,
                                          y_score = tree_tuned_pred).round(4)
# Out:
# Training ACCURACY: 0.7121
# Testing  ACCURACY: 0.7125
# AUC Score        : 0.6225

# %% [markdown]
# **Here we got the good AUC score >0.62.**

# %% [markdown]
# ## Random Forest Classification

# %% [markdown]
# ### Full model

# %%
###### Non Standardized Preparation 
# Defining explanatory variables (add according to new feature selections)
data_rf = data.loc[: , variables_dict['Full_Model']]

# train-test split with stratification
x_train, x_test, y_train, y_test = train_test_split(
            data_rf,  # change
            data_target,
            test_size = 0.25,
            random_state = 219,
            stratify = data_target) # stratifying target variable to ensure balance

# merging training data for statsmodels
data_train = pd.concat([x_train, y_train], axis = 1) # contains target variable!

# INSTANTIATING a random forest model
rf = RandomForestClassifier(n_estimators     = 1000,
                                    criterion        = 'gini',
                                    max_depth        = 8,
                                    min_samples_leaf = 1,
                                    bootstrap        = True,
                                    warm_start       = False,
                                    random_state     = 219)

# FITTING the training data
rf_fit = rf.fit(x_train, y_train.values.reshape(-1,))

# PREDICTING based on the testing set
rf_pred = rf_fit.predict(x_test)

rf_train_acc2 = rf_fit.score(x_train, y_train).round(4)
rf_test_acc2  = rf_fit.score(x_test, y_test).round(4)
rf_auc_score2 = roc_auc_score(y_true  = y_test,
                             y_score = rf_pred).round(4)
# SCORING the results
print('Training ACCURACY:', rf_train_acc2)
print('Testing  ACCURACY:', rf_test_acc2)
print('AUC Score        :', rf_auc_score2)
# Out:
# Training ACCURACY: 0.8376
# Testing  ACCURACY: 0.6879
# AUC Score        : 0.5264

# %% [markdown]
# ### Important Model

# %%
###### Non Standardized Preparation 
# Defining explanatory variables (add according to new feature selections)
data_rf = data.loc[: , variables_dict['Important_Model']]

# train-test split with stratification
x_train, x_test, y_train, y_test = train_test_split(
            data_rf,  # change
            data_target,
            test_size = 0.25,
            random_state = seed,
            stratify = data_target) # stratifying target variable to ensure balance

# merging training data for statsmodels
data_train = pd.concat([x_train, y_train], axis = 1) # contains target variable!

# INSTANTIATING a random forest model
rf = RandomForestClassifier(n_estimators     = 1000,
                                    criterion        = 'entropy',
                                    max_depth        = None,
                                    min_samples_leaf = 1,
                                    bootstrap        = True,
                                    warm_start       = False,
                                    random_state     = 219)

# FITTING the training data
rf_fit = rf.fit(x_train, y_train.values.reshape(-1,))

# PREDICTING based on the testing set
rf_pred = rf_fit.predict(x_test)

rf_train_acc2 = rf_fit.score(x_train, y_train).round(4)
rf_test_acc2  = rf_fit.score(x_test, y_test).round(4)
rf_auc_score2 = roc_auc_score(y_true  = y_test,
                             y_score = rf_pred).round(4)
# SCORING the results
print('Training ACCURACY:', rf_train_acc2)
print('Testing  ACCURACY:', rf_test_acc2)
print('AUC Score        :', rf_auc_score2)
# Out:
# Training ACCURACY: 1.0
# Testing  ACCURACY: 0.6838
# AUC Score        : 0.5606

# %% [markdown]
# ### Base Model

# %%
###### Non Standardized Preparation 
# Defining explanatory variables (add according to new feature selections)
data_rf = data.loc[: , variables_dict['Base']]

# train-test split with stratification
x_train, x_test, y_train, y_test = train_test_split(
            data_rf,  # change
            data_target,
            test_size = 0.25,
            random_state = seed,
            stratify = data_target) # stratifying target variable to ensure balance

# merging training data for statsmodels
data_train = pd.concat([x_train, y_train], axis = 1) # contains target variable!

# INSTANTIATING a random forest model
rf = RandomForestClassifier(n_estimators     = 100,
                                    criterion        = 'gini',
                                    max_depth        = None,
                                    min_samples_leaf = 1,
                                    bootstrap        = True,
                                    warm_start       = False,
                                    random_state     = 219)

# FITTING the training data
rf_fit = rf.fit(x_train, y_train.values.reshape(-1,))

# PREDICTING based on the testing set
rf_pred = rf_fit.predict(x_test)

rf_train_acc2 = rf_fit.score(x_train, y_train).round(4)
rf_test_acc2  = rf_fit.score(x_test, y_test).round(4)
rf_auc_score2 = roc_auc_score(y_true  = y_test,
                             y_score = rf_pred).round(4)
# SCORING the results
print('Training ACCURACY:', rf_train_acc2)
print('Testing  ACCURACY:', rf_test_acc2)
print('AUC Score        :', rf_auc_score2)
# Out:
# Training ACCURACY: 1.0
# Testing  ACCURACY: 0.6899
# AUC Score        : 0.5736

# %% [markdown]
# ### Hypertuning

# %%
'''
data_expl=data.loc[: , variables_dict['Important_Model']]
# declaring a hyperparameter space
estimator_space  = pd.np.arange(100, 2000, 250)
leaf_space       = pd.np.arange(1, 50, 10)
max_depth        = np.arange(1, 20, 1)
criterion_space  = ['gini', 'entropy']
bootstrap_space  = [True, False]
warm_start_space = [True, False]


# creating a hyperparameter grid
param_grid = {'n_estimators'     : estimator_space,
              'min_samples_leaf' : leaf_space,
              'max_depth'        : max_depth,
              'criterion'        : criterion_space,
              'bootstrap'        : bootstrap_space,
              'warm_start'       : warm_start_space}


# INSTANTIATING the model object without hyperparameters
forest_grid = RandomForestClassifier(random_state = 219)


# GridSearchCV object
forest_cv = RandomizedSearchCV(estimator           = forest_grid,
                               param_distributions = param_grid,
                               cv         = 3,
                               n_iter     = 1000,
                               scoring    = make_scorer(roc_auc_score,
                                            needs_threshold = False))


# FITTING to the FULL DATASET (due to cross-validation)
forest_cv.fit(data_expl, data_target)


# PREDICT step is not needed


# printing the optimal parameters and best score
print("Tuned Parameters  :", forest_cv.best_params_)
print("Tuned Training AUC:", forest_cv.best_score_.round(4))
'''
# Out:
# '\ndata_expl=data.loc[: , variables_dict[\'Important_Model\']]\n# declaring a hyperparameter space\nestimator_space  = pd.np.arange(100, 2000, 250)\nleaf_space       = pd.np.arange(1, 50, 10)\nmax_depth        = np.arange(1, 20, 1)\ncriterion_space  = [\'gini\', \'entropy\']\nbootstrap_space  = [True, False]\nwarm_start_space = [True, False]\n\n\n# creating a hyperparameter grid\nparam_grid = {\'n_estimators\'     : estimator_space,\n              \'min_samples_leaf\' : leaf_space,\n              \'max_depth\'        : max_depth,\n              \'criterion\'        : criterion_space,\n              \'bootstrap\'        : bootstrap_space,\n              \'warm_start\'       : warm_start_space}\n\n\n# INSTANTIATING the model object without hyperparameters\nforest_grid = RandomForestClassifier(random_state = 219)\n\n\n# GridSearchCV object\nforest_cv = RandomizedSearchCV(estimator           = forest_grid,\n                               param_distributions = param_grid,\n               
# ...

# %% [markdown]
# ### Tuned Parameter

# %%
# building a model based on hyperparameter tuning results

# copy/pasting in the best_estimator_ results
# to avoid running another RandomizedSearch
forest_tuned = RandomForestClassifier(criterion='entropy', max_depth=8, n_estimators=1350,
                       random_state=219)


# FITTING the model objectwertzuü+
forest_tuned_fit = forest_tuned.fit(x_train, y_train)


# PREDICTING based on the testing set
forest_tuned_pred = forest_tuned_fit.predict(x_test)


# SCORING the results
print('Forest Tuned Training ACCURACY:', forest_tuned.score(x_train, y_train).round(4))
print('Forest Tuned Testing  ACCURACY:', forest_tuned.score(x_test, y_test).round(4))
print('Forest Tuned AUC Score        :', roc_auc_score(y_true  = y_test,
                                                       y_score = forest_tuned_pred).round(4))
# Out:
# Forest Tuned Training ACCURACY: 0.8177
# Forest Tuned Testing  ACCURACY: 0.7064
# Forest Tuned AUC Score        : 0.5671

# %% [markdown]
# ## Gradient Booster

# %% [markdown]
# ### Important Model

# %%
#INSTANTIATING Model
full_gbm_default = GradientBoostingClassifier()

#Fitting the model
full_gbm_default_fit = full_gbm_default.fit(x_train, y_train)

#PREDICT with the model
full_gbm_default_pred = full_gbm_default_fit.predict(x_test)

#Scoring results
full_gbm_train_score = full_gbm_default.score(x_train,y_train).round(4)
full_gbm_test_score = full_gbm_default.score(x_test,y_test).round(4)
full_gbm_auc_score = roc_auc_score(y_true = y_test,
                                             y_score = full_gbm_default_pred).round(4)


#Printing the scores
print("GBM Default Training ACCURACY:", full_gbm_default.score(x_train,y_train).round(4))
print("GBM Default Testing ACCURACY:", full_gbm_default.score(x_test, y_test).round(4))
print("GBM Default AUC Score:", roc_auc_score(y_true = y_test,
                                             y_score = full_gbm_default_pred).round(4))
# Out:
# GBM Default Training ACCURACY: 0.7937
# GBM Default Testing ACCURACY: 0.7043
# GBM Default AUC Score: 0.5944

# %% [markdown]
# ### Hypertuning

# %%
'''
#declaring hyperparameter space
learn_space      = np.arange(0.1, 2.0, 0.2)
estimator_space = np.arange(100, 200, 25)
criterion       = ['friedman_mse', 'mse', 'mae']
#sample_split    = np.ararange(2, 20, 1)
sample_leaf     = np.arange(5, 30, 2)
max_depth       = np.arange(2, 20, 2)
warm_start      = [False, True]

#creating hyperparameter grid
param_grid = {'learning_rate' : learn_space,
             'n_estimators'   : estimator_space,
             'criterion'      : criterion,
             'min_samples_leaf':sample_leaf,
             'max_depth'      : max_depth,
             'warm_start'     : warm_start}

#INSTANTIATING Model
gbm_tuned = GradientBoostingClassifier(random_state=219)

#Randomized Search CV process
gbm_tuned_cv = RandomizedSearchCV(estimator         = gbm_tuned,
                                 param_distributions= param_grid,
                                 cv                 = 3,
                                 n_iter             = 50,
                                 random_state       = 219,
                                 scoring            = make_scorer(roc_auc_score,
                                                 needs_threshold = False))

#Fitting the model
gbm_tuned_cv.fit(chef_expl, chef_target)

#Predicting on the model - not required at this point


# printing the optimal parameters and best score
print("Tuned Parameters  :", gbm_tuned_cv.best_params_)
print("Tuned Training AUC:", gbm_tuned_cv.best_score_.round(4))
'''
# Out:
# '\n#declaring hyperparameter space\nlearn_space      = np.arange(0.1, 2.0, 0.2)\nestimator_space = np.arange(100, 200, 25)\ncriterion       = [\'friedman_mse\', \'mse\', \'mae\']\n#sample_split    = np.ararange(2, 20, 1)\nsample_leaf     = np.arange(5, 30, 2)\nmax_depth       = np.arange(2, 20, 2)\nwarm_start      = [False, True]\n\n#creating hyperparameter grid\nparam_grid = {\'learning_rate\' : learn_space,\n             \'n_estimators\'   : estimator_space,\n             \'criterion\'      : criterion,\n             \'min_samples_leaf\':sample_leaf,\n             \'max_depth\'      : max_depth,\n             \'warm_start\'     : warm_start}\n\n#INSTANTIATING Model\ngbm_tuned = GradientBoostingClassifier(random_state=219)\n\n#Randomized Search CV process\ngbm_tuned_cv = RandomizedSearchCV(estimator         = gbm_tuned,\n                                 param_distributions= param_grid,\n                                 cv                 = 3,\n                                 n_iter
# ...

# %% [markdown]
# ### Tuned Model

# %%
#INSTANTIATING Tuned Model
gbm_tuned = GradientBoostingClassifier(learning_rate=0.30000000000000004, max_depth=2,
                           min_samples_leaf=25, random_state=219) # for 0.05

#Fitting the model
gbm_tuned_fit = gbm_tuned.fit(x_train, y_train)

#PREDICT with the model
gbm_tuned_pred = gbm_tuned_fit.predict(x_test)

#Scoring results
tuned_gbm_train_score = gbm_tuned.score(x_train,y_train).round(4)
tuned_gbm_test_score = gbm_tuned.score(x_test,y_test).round(4)
tuned_gbm_auc_score = roc_auc_score(y_true = y_test,
                                             y_score = gbm_tuned_pred).round(4)


#Printing the scores
print("GBM Default Training ACCURACY:", gbm_tuned.score(x_train,y_train).round(4))
print("GBM Default Testing ACCURACY:", gbm_tuned.score(x_test, y_test).round(4))
print("GBM Default AUC Score:", roc_auc_score(y_true = y_test,
                                             y_score = gbm_tuned_pred).round(4))
# Out:
# GBM Default Training ACCURACY: 0.7937
# GBM Default Testing ACCURACY: 0.6838
# GBM Default AUC Score: 0.5877

# %% [markdown]
# # Best Model

# %% [markdown]
# **The Best output that I got is from tuned decision model that has been trained and tested on a dataset. The model's training accuracy is 0.7121, which means it correctly predicted the type of 71.21% of the training samples. The model's test accuracy was 0.7125, which means it correctly predicted the type of 71.25% of the test sample.**
#
# **The training test deviation is the difference between the training and test accuracy, very small in this case 0.0004.**
#
# **The model's AUC score is 0.6225, which represents the area under the receiver operating characteristic (ROC) curve.**
#
# **The confusion matrix is a table that summarizes the model's performance by showing the number of true positives, true negatives, false positives, and false negatives. In this case, the confusion matrix showed that the model correctly predicted 58 true negatives and 289 true positives, but incorrectly predicted 98 false negatives and 42 false positives.**

# %%
####### Non Standardized Preparation 
## Defining explanatory variables (add according to new feature selections)
data_base = data.loc[: , variables_dict['Important_Model']]

## train-test split with stratification
x_train, x_test, y_train, y_test = train_test_split(
           data_base,  # change
            data_target,
           test_size = 0.25,
            random_state = 219,
            stratify = data_target) # stratifying target variable to ensure balance

## merging training data for statsmodels
chef_train = pd.concat([x_train, y_train], axis = 1) # contains target variable!
tree_tuned = DecisionTreeClassifier(criterion='entropy',
                                    max_depth=2,
                                    min_samples_leaf=14, min_samples_split=19, 
                                    random_state=219, splitter='best')


# FITTING to the FULL DATASET (due to cross-validation from GridSearch)
tree_tuned_fit = tree_tuned.fit(data_base, data_target)

# PREDICTING based on the testing set
tree_tuned_pred = tree_tuned.predict(x_test)

# compute confusion matrix
conf_mat = confusion_matrix(y_test, tree_tuned_pred)

gap= tree_tuned.score(x_test, y_test).round(4)-tree_tuned.score(x_train, y_train).round(4)


# SCORING the results
print('Model:  Tuned Decision Model')
print('Training ACCURACY:', tree_tuned.score(x_train, y_train).round(4))
print('Testing  ACCURACY:', tree_tuned.score(x_test, y_test).round(4))
print('Train-Test Gap:', gap.round(4))
print('AUC Score        :', roc_auc_score(y_true  = y_test,
                                          y_score = tree_tuned_pred).round(4))
# print confusion matrix
print('Confusion matrix:\n', conf_mat)
# Out:
# Model:  Tuned Decision Model
# Training ACCURACY: 0.7121
# Testing  ACCURACY: 0.7125
# Train-Test Gap: 0.0004
# AUC Score        : 0.6225
# Confusion matrix:
#  [[ 58  98]
#  [ 42 289]]

# %%
print(
    f'''
   ___ _               _  __ _           _   _                                    _      _  
  / __\ | __ _ ___ ___(_)/ _(_) ___ __ _| |_(_) ___  _ __         /\/\   ___   __| | ___| | 
 / /  | |/ _` / __/ __| | |_| |/ __/ _` | __| |/ _ \| '_ \       /    \ / _ \ / _` |/ _ \ | 
/ /___| | (_| \__ \__ \ |  _| | (_| (_| | |_| | (_) | | | |     / /\/\ \ (_) | (_| |  __/ | 
\____/|_|\__,_|___/___/_|_| |_|\___\__,_|\__|_|\___/|_| |_|     \/    \/\___/ \__,_|\___|_| 
                                                                                            
    
         ---------------------------------------------------------------------------
         |*|*********************************************************************|*|
         |*| --------------------------------------------------------------------|*|
         |*| Model               :         {model}             |*|
         |*| Training Accuracy   :             {a}                            |*|
         |*| Testing Accuracy    :             {b}                            |*|
         |*| Test_Train gap      :             {gap}            |*|
         |*| AUC Score           :             {c}                            |*|
         |*| --------------------------------------------------------------------|*|       
         |*|*********************************************************************|*|                              
         ---------------------------------------------------------------------------                               
                                        
                                        
                                        
                                        ''')
# print confusion matrix
print('Confusion matrix:\n', conf_mat)

sns.heatmap(conf_mat, annot=True, cmap="Blues", fmt="d")

plt.title("Confusion Matrix for Logistics Regression Model")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
#    ___ _               _  __ _           _   _                                    _      _
#   / __\ | __ _ ___ ___(_)/ _(_) ___ __ _| |_(_) ___  _ __         /\/\   ___   __| | ___| |
#  / /  | |/ _` / __/ __| | |_| |/ __/ _` | __| |/ _ \| '_ \       /    \ / _ \ / _` |/ _ \ |
# / /___| | (_| \__ \__ \ |  _| | (_| (_| | |_| | (_) | | | |     / /\/\ \ (_) | (_| |  __/ |
# \____/|_|\__,_|___/___/_|_| |_|\___\__,_|\__|_|\___/|_| |_|     \/    \/\___/ \__,_|\___|_|
#
#
#          ---------------------------------------------------------------------------
#          |*|*********************************************************************|*|
#          |*| --------------------------------------------------------------------|*|
#          |*| Model               :         Tuned Classification Tree             |*|
#          |*| Training Accuracy   :             0.7121                            |*|
#          |*| Testing Accuracy    :             0.7125                            |*|
# ...
