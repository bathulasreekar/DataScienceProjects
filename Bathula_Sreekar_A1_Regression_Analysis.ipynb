# %% [markdown]
# <table align="left" width=100%>
#             <div align="center">
#                 <font color="#21618C" size=16px>
#                   <b> Regression Model Development </b>
#                 </font>
#     </div>
# </table>
#
#
#
# <table align="left" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=6px>
#                   <b> Computational Data Analytics with Python </b>
#                 </font>
#     </div>
# </table>
#
#
#
#
# <table align="right">
#     <tr>
#         <td width="15%">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b><br>
#                         Name       : Sreekar Bathula<br>
#                         Student id : 28067764<br>
#                         Course     : Master's in Business Analytics<br>
#                         School     : Hult International Business School
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
#
#
# <table align="center" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=6px>
# <b> ___________________________________________________________________________________________________________ </b>
#                 </font>
#     </div>
# </table>
#
#
# <table align="left" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=26px>
#                     <b> Apprentice Chef </u>
#                 </font>
#     </div>
# </table>

# %% [markdown]
# ## Basic Start

# %% [markdown]
# **Apprentice Chef, Inc. is an innovative company with a unique vision of home cooking to support the busy lifestyle of working professionals with healthy and delicious diet.**
#
# **Approach**
# 1) Understanding the data.
#
# 2) Cleaning the data.
#
# 3) Performing the exploratory data analysis.
#
# 4) Feature Engineering.
#
# 5) Modelling.
#
# **Understanding data:**
# In this step, I got familiar with the data which involves understanding the context and domain of the data, identifying variables and their types, checking for missing values, and discovering basic statistics such as mean, median, and mean values. standard deviation.
#
# **Data cleaning:**
# In this step, cleaning the data to remove any errors or inconsistencies that could affect the analysis. This also involved handling missing values, handling outliers and outliers, and removing duplicate or unrelated data.
#
# **Perform Exploratory Data Analysis (EDA):**
# In this step, I explore more data to better understand and understand the relationship between variables. It involves visualizing data using graphs and charts, calculating statistical measures such as correlations and distributions, and identifying patterns and trends in the data.
#
# **Technical features:**
# In this step, I converted the data to a format suitable for modeling. It involves selecting relevant features, transforming variables, and creating new variables or features that collect useful information from the data.
#
# **Modelling:**
# In this step, you need to create a predictive model that can generalize well to the new data. This involves choosing an appropriate algorithm, dividing the data into training and test sets, training the model on the training data, evaluating the model on the test data, and fine-tuning the parameters. of the model to optimize the performance of the model.

# %% [markdown]
# ### Importing libraries

# %%
# importing libraries
import numpy as np
import pandas as pd # data science essentials
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # enhanced data visualization
import statsmodels.formula.api as smf # regression modeling
from sklearn.model_selection import train_test_split # train/test split
import sklearn.linear_model # linear modeling in scikit-learn 
from sklearn.ensemble import RandomForestRegressor #importing Random Forest
from sklearn.neighbors import KNeighborsRegressor # KNN for Regression

# %% [markdown]
# ### Importing data from excel

# %%
#Reading the data from excel

# specifying the path and file name
file = 'Apprentice_Chef_Dataset_2023.xlsx'

# reading the file into Python
data=pd.read_excel(file)

# checking the file and displaying the first 5 rows
data.head(n = 5)
# Out:
#    REVENUE                    NAME                             EMAIL  \
# 0   4920.0       Steffon Baratheon       steffon.baratheon@yahoo.com
# 1   6150.0          Harlon Greyjoy           harlon.greyjoy@visa.com
# 2   3435.0                 Monster            monster@protonmail.com
# 3   3330.0  Damon Lannister (lord)  damon.lannister.(lord)@yahoo.com
# 4   3427.5      Raynald Westerling        raynald.westerling@jnj.com
#
#   FIRST_NAME FAMILY_NAME  TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  \
# 0    Steffon   Baratheon                  493                   9
# 1     Harlon     Greyjoy                  361                   9
# 2    Monster     Monster                  278                   6
# 3      Damon  Lannister                   269                   8
# 4    Raynald  Westerling                  276                   7
#
#    CONTACTS_W_CUSTOMER_SERVICE  PRODUCT_CATEGORIES_VIEWED  \
# 0                            1                         10
# ...

# %% [markdown]
# **Data Description - The variables of the dataset contains Revenue, Name, Email_id, Firstname, Family name, Total meals ordered, Unique meals purchased, contacts to customer services, product categories viewed, Average time per site, Cancellation afternoon, PC logins,Mobile logins, Weekly plan, Late delivery, Average Preparation video time, Largest Order size, Average mean rating, Total photos viewed.**

# %% [markdown]
# ## Understanding the data

# %% [markdown]
# ### Obtaining the shape of data set

# %%
# formatting and printing the dimensions of the dataset
print(f"""
Size of Original Dataset
------------------------
Observations: {data.shape[0]}
Features:     {data.shape[1]}
""")
# Out:
# Size of Original Dataset
# ------------------------
# Observations: 1946
# Features:     19

# %% [markdown]
# **From the above dimensional table we confirm that there are 19 column and 1946 rows of data.**

# %% [markdown]
# ### Checking the columns, Number of null values, Data types

# %%
# INFOrmation about each variable
data.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   REVENUE                      1946 non-null   float64
#  1   NAME                         1946 non-null   object
#  2   EMAIL                        1946 non-null   object
#  3   FIRST_NAME                   1946 non-null   object
#  4   FAMILY_NAME                  1900 non-null   object
#  5   TOTAL_MEALS_ORDERED          1946 non-null   int64
#  6   UNIQUE_MEALS_PURCH           1946 non-null   int64
#  7   CONTACTS_W_CUSTOMER_SERVICE  1946 non-null   int64
#  8   PRODUCT_CATEGORIES_VIEWED    1946 non-null   int64
#  9   AVG_TIME_PER_SITE_VISIT      1946 non-null   float64
#  10  CANCELLATIONS_AFTER_NOON     1946 non-null   int64
#  11  PC_LOGINS                    1946 non-null   int64
#  12  MOBILE_LOGINS                1946 non-null   int64
# ...

# %% [markdown]
# **From the above information table, I found that there are 46 null values in the FAMILY_NAME column.**

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# ### Filling the missing data

# %%
# extracting family name from full name and fill in missing values
data['FAMILY_NAME'] = data['FAMILY_NAME'].fillna(data['NAME'].str.split().str[-1])

# %% [markdown]
# **There are 46 missing value there filled by splitting the full name**

# %% [markdown]
# ### Correcting Column names

# %%
# Renaming the columnn name of Largest_order_size and Late_deliveries as they are mis-spelled
data=data.rename(columns={'LARGEST_ORDER_SIZE':'AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'})
data=data.rename(columns={'LATE_DELIVERIES ':'LATE_DELIVERIES'})
data.head(2)
# Out:
#    REVENUE               NAME                        EMAIL FIRST_NAME  \
# 0   4920.0  Steffon Baratheon  steffon.baratheon@yahoo.com    Steffon
# 1   6150.0     Harlon Greyjoy      harlon.greyjoy@visa.com     Harlon
#
#   FAMILY_NAME  TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  \
# 0   Baratheon                  493                   9
# 1     Greyjoy                  361                   9
#
#    CONTACTS_W_CUSTOMER_SERVICE  PRODUCT_CATEGORIES_VIEWED  \
# 0                            1                         10
# 1                            1                          6
#
#    AVG_TIME_PER_SITE_VISIT  CANCELLATIONS_AFTER_NOON  PC_LOGINS  \
# 0                    265.6                         5          5
# 1                    247.0                         2          5
#
#    MOBILE_LOGINS  WEEKLY_PLAN  LATE_DELIVERIES  AVG_PREP_VID_TIME  \
# 0              2            0                0             137.41
# 1              1            0                0             120.20
#
# ...

# %% [markdown]
# **There are some column names are mis-spelled, they are corrected**

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Statistical Description

# %%
#describing the data statistically
data.describe()
# Out:
#            REVENUE  TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  \
# count  1946.000000          1946.000000         1946.000000
# mean   2107.292652            74.634121            6.983556
# std    1138.290709            55.309782            2.281193
# min     131.000000            11.000000            1.000000
# 25%    1350.000000            39.000000            5.000000
# 50%    1740.000000            60.000000            7.000000
# 75%    2670.000000            95.000000            8.000000
# max    8793.750000           493.000000           18.000000
#
#        CONTACTS_W_CUSTOMER_SERVICE  PRODUCT_CATEGORIES_VIEWED  \
# count                  1946.000000                1946.000000
# mean                      4.904933                   5.383864
# std                       2.502175                   3.044001
# min                       1.000000                   1.000000
# 25%                       3.000000                   3.000000
# ...

# %% [markdown]
# **Finding the Statistical description of the dataset**

# %% [markdown]
# #### NUMERICAL VARIABLES

# %%
#Prininting the mumerical columns in the dataset 
data_num = data.select_dtypes(include=np.number)
data_num.columns
# Out:
# Index(['REVENUE', 'TOTAL_MEALS_ORDERED', 'UNIQUE_MEALS_PURCH',
#        'CONTACTS_W_CUSTOMER_SERVICE', 'PRODUCT_CATEGORIES_VIEWED',
#        'AVG_TIME_PER_SITE_VISIT', 'CANCELLATIONS_AFTER_NOON', 'PC_LOGINS',
#        'MOBILE_LOGINS', 'WEEKLY_PLAN', 'LATE_DELIVERIES', 'AVG_PREP_VID_TIME',
#        'AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER', 'AVG_MEAN_RATING',
#        'TOTAL_PHOTOS_VIEWED'],
#       dtype='object')

# %% [markdown]
# **Displaying the numerical variables in the data set**

# %% [markdown]
# ##### REVENUE

# %%
#Descriptive statistics of column REVENUE
count_value=data['REVENUE'].count() #getting the data count of values in Revenue column
min_value= data['REVENUE'].min() #getting the data of min value in the column revenue
max_value=data['REVENUE'].max() #finding the max value in the column
mean_value=data['REVENUE'].mean() #finding the mean
median_value=data['REVENUE'].median() #finding the median
mode_value=data['REVENUE'].mode() #finding the mode
variance_val=data['REVENUE'].var() #finding the variance
std_value=data['REVENUE'].std() #finding the standard deviation
q25_value=data['REVENUE'].quantile(0.25)#finding the interquartile range
q50_value=data['REVENUE'].quantile(0.50)
q75_value=data['REVENUE'].quantile(0.75)
data_type=data['REVENUE'].dtype #finding the datatype
skew_value=data['REVENUE'].skew() #finding the skewness value
kurt_value=data['REVENUE'].kurt() #finding the kurthosis

#Printing all our required data to describe our data
print(f'''
      REVENUE
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
#       REVENUE
# ---------------------
# data type:float64
# count:    1946
#
# min:      131.0
# max:      8793.75
#
# mean:     2107.292651593011
# median:   1740.0
# mode:     1350.0
#
# variance: 1295705.7378489315
# Std Devn: 1138.2907088476702
#
# Skewness: 1.6265732421573793
# Kurtosis: 3.354570268438312
#
# IQR 25%:  1350.0
# IQR 50%:  1740.0
# IQR 75%:  2670.0

# %% [markdown]
# **Stastical analysis on the Revenue showed that the normal distribution graph is not symnetic and is right skewed (skew>0) and has thick outliers on the right(kurthosis>0)**

# %%
#Drawing the histogram to see how our data is distributed
plt.figure(figsize=(8,4))
data['REVENUE'].hist()
plt.xlabel('REVENUE')

#marking the mean, median, mode to the histogram
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Making a kde plot see our distibution and peakness of the curve
sns.kdeplot(data['REVENUE'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a box plot to see our outliers
plt.figure(figsize=(8,6))
plt.boxplot(data['REVENUE'])
plt.show()

# %% [markdown]
# **From the above plots I found that there many outlier in the upper limit. The curve is not symantric and is skewed to right.**

# %% [markdown]
# ##### TOTAL_MEALS_ORDERED

# %%
#Descriptive statistics of column Total_meals_ordered
count_value=data['TOTAL_MEALS_ORDERED'].count() #finding the value counts.
min_value= data['TOTAL_MEALS_ORDERED'].min() #finding the min value.
max_value=data['TOTAL_MEALS_ORDERED'].max() #Finding the max value.
mean_value=data['TOTAL_MEALS_ORDERED'].mean() #Finding the Mean.
median_value=data['TOTAL_MEALS_ORDERED'].median() #Finding the Median
mode_value=data['TOTAL_MEALS_ORDERED'].mode() #Finding the mode
variance_val=data['TOTAL_MEALS_ORDERED'].var() #Finding the variance
std_value=data['TOTAL_MEALS_ORDERED'].std() #Finding the Standard_deviation
q25_value=data['TOTAL_MEALS_ORDERED'].quantile(0.25) #Finding the IQR
q50_value=data['TOTAL_MEALS_ORDERED'].quantile(0.50)
q75_value=data['TOTAL_MEALS_ORDERED'].quantile(0.75)
data_type=data['TOTAL_MEALS_ORDERED'].dtype #Checking the data_type
skew_value=data['TOTAL_MEALS_ORDERED'].skew() #Checking the skewness
kurt_value=data['TOTAL_MEALS_ORDERED'].kurt() #Checking the Kurthosis

#Printing all the required statistical data
print(f'''
      TOTAL_MEALS_ORDERED
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
#       TOTAL_MEALS_ORDERED
# ---------------------
# data type:int64
# count:    1946
#
# min:      11
# max:      493
#
# mean:     74.63412127440904
# median:   60.0
# mode:     15
#
# variance: 3059.1719765282237
# Std Devn: 55.30978192443199
#
# Skewness: 2.006653112711204
# Kurtosis: 6.199523584091642
#
# IQR 25%:  39.0
# IQR 50%:  60.0
# IQR 75%:  95.0

# %%
#Making the histogram to checking the data
plt.figure(figsize=(8,4))
data['TOTAL_MEALS_ORDERED'].hist()
plt.xlabel('TOTAL_MEALS_ORDERED')


plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting the kde graph to check or data distribution and outliers
sns.kdeplot(data['TOTAL_MEALS_ORDERED'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting the box plot to check the outliers
plt.figure(figsize=(8,6))
plt.boxplot(data['TOTAL_MEALS_ORDERED'])
plt.show()

# %% [markdown]
# **From the exploratory data analysis, I infer that the data distribution is skeweed to right**

# %% [markdown]
# ##### UNIQUE_MEALS_PURCH

# %%
#Descriptive statistics of column Unique_meal_purch
count_value=data['UNIQUE_MEALS_PURCH'].count() #Finding the count 
min_value= data['UNIQUE_MEALS_PURCH'].min() #Finding the Min value
max_value=data['UNIQUE_MEALS_PURCH'].max() #Finding the Max value
mean_value=data['UNIQUE_MEALS_PURCH'].mean() #Finding the Mean
median_value=data['UNIQUE_MEALS_PURCH'].median() # Finding the median
mode_value=data['UNIQUE_MEALS_PURCH'].mode() #Finding the mode
variance_val=data['UNIQUE_MEALS_PURCH'].var() #Finding the variance
std_value=data['UNIQUE_MEALS_PURCH'].std() #Finding the standard deviation
q25_value=data['UNIQUE_MEALS_PURCH'].quantile(0.25) #Finding the IQR
q50_value=data['UNIQUE_MEALS_PURCH'].quantile(0.50)
q75_value=data['UNIQUE_MEALS_PURCH'].quantile(0.75)
data_type=data['UNIQUE_MEALS_PURCH'].dtype #Finding the Data type
skew_value=data['UNIQUE_MEALS_PURCH'].skew() #Finding the Skewness
kurt_value=data['UNIQUE_MEALS_PURCH'].kurt() #Finding the kurthosis

#Printing all the require statistical data
print(f'''
UNIQUE_MEALS_PURCH
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
# UNIQUE_MEALS_PURCH
# ---------------------
# data type:int64
# count:    1946
#
# min:      1
# max:      18
#
# mean:     6.983556012332991
# median:   7.0
# mode:     7
#
# variance: 5.203842566783964
# Std Devn: 2.2811932331093665
#
# Skewness: 0.56601546122749
# Kurtosis: 0.028415757777829675
#
# IQR 25%:  5.0
# IQR 50%:  7.0
# IQR 75%:  8.0

# %%
#Plotting the Histogram
plt.figure(figsize=(10,10))
data['UNIQUE_MEALS_PURCH'].hist()
plt.xlabel('UNIQUE_MEALS_PURCH')


plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting the kde plot
sns.kdeplot(data['UNIQUE_MEALS_PURCH'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a box plot
plt.figure(figsize=(8,6))
plt.boxplot(data['UNIQUE_MEALS_PURCH'])
plt.show()

# %% [markdown]
# **From the above exploratory data analysis, I infer that the normal distribution graph is almost symentric.**

# %% [markdown]
# ##### CONTACTS_W_CUSTOMER_SERVICE

# %%
#Descriptive statistics for thhe column Contacts_w_customer_service
count_value=data['CONTACTS_W_CUSTOMER_SERVICE'].count() #finding the value counts
min_value= data['CONTACTS_W_CUSTOMER_SERVICE'].min()#Finding the minimun value
max_value=data['CONTACTS_W_CUSTOMER_SERVICE'].max() #Finding the max value
mean_value=data['CONTACTS_W_CUSTOMER_SERVICE'].mean() #Finding the mean
median_value=data['CONTACTS_W_CUSTOMER_SERVICE'].median() #Finding he median
mode_value=data['CONTACTS_W_CUSTOMER_SERVICE'].mode() #Finding the mode
variance_val=data['CONTACTS_W_CUSTOMER_SERVICE'].var() #Finding the Variance
std_value=data['CONTACTS_W_CUSTOMER_SERVICE'].std() #Finding the Standard deviation
q25_value=data['CONTACTS_W_CUSTOMER_SERVICE'].quantile(0.25) #finding the IQR
q50_value=data['CONTACTS_W_CUSTOMER_SERVICE'].quantile(0.50)
q75_value=data['CONTACTS_W_CUSTOMER_SERVICE'].quantile(0.75)
data_type=data['CONTACTS_W_CUSTOMER_SERVICE'].dtype #Finding the Data type
skew_value=data['CONTACTS_W_CUSTOMER_SERVICE'].skew() #Finding the Skewness
kurt_value=data['CONTACTS_W_CUSTOMER_SERVICE'].kurt() #Finding the Kurthosis

#Printing all the stastical data
print(f'''
CONTACTS_W_CUSTOMER_SERVICE
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
# CONTACTS_W_CUSTOMER_SERVICE
# ---------------------
# data type:int64
# count:    1946
#
# min:      1
# max:      19
#
# mean:     4.904933196300103
# median:   5.0
# mode:     3
#
# variance: 6.260880535380708
# Std Devn: 2.502175160811231
#
# Skewness: 0.3708329731884767
# Kurtosis: -0.05795258922186308
#
# IQR 25%:  3.0
# IQR 50%:  5.0
# IQR 75%:  7.0

# %%
#Plotting the Histogram
plt.figure(figsize=(8,4))
data['CONTACTS_W_CUSTOMER_SERVICE'].hist()
plt.xlabel('CONTACTS_W_CUSTOMER_SERVICE')


plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting the kdeplot
sns.kdeplot(data['CONTACTS_W_CUSTOMER_SERVICE'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting the box plot
plt.figure(figsize=(8,6))
plt.boxplot(data['CONTACTS_W_CUSTOMER_SERVICE'])
plt.show()

# %% [markdown]
# **Data is almost symentric with skewness and kurthosis which is almost equivalent to zero with less outliers**

# %% [markdown]
# ##### PRODUCT_CATEGORIES_VIEWED

# %%
#Descriptive statistics for thhe column Product_categories_viewed
count_value=data['PRODUCT_CATEGORIES_VIEWED'].count() #value_count
min_value= data['PRODUCT_CATEGORIES_VIEWED'].min() #Minimum value
max_value=data['PRODUCT_CATEGORIES_VIEWED'].max() #maximum value
mean_value=data['PRODUCT_CATEGORIES_VIEWED'].mean() #mean
median_value=data['PRODUCT_CATEGORIES_VIEWED'].median() #Median
mode_value=data['PRODUCT_CATEGORIES_VIEWED'].mode() #Mode
variance_val=data['PRODUCT_CATEGORIES_VIEWED'].var() #Variance
std_value=data['PRODUCT_CATEGORIES_VIEWED'].std() #Standard Deviation
q25_value=data['PRODUCT_CATEGORIES_VIEWED'].quantile(0.25) #IQR
q50_value=data['PRODUCT_CATEGORIES_VIEWED'].quantile(0.50)
q75_value=data['PRODUCT_CATEGORIES_VIEWED'].quantile(0.75)
data_type=data['PRODUCT_CATEGORIES_VIEWED'].dtype #Data_type
skew_value=data['PRODUCT_CATEGORIES_VIEWED'].skew() #Skewness
kurt_value=data['PRODUCT_CATEGORIES_VIEWED'].kurt() #Kurthosis

#Printing all the required statistical data
print(f'''
PRODUCT_CATEGORIES_VIEWED
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
# PRODUCT_CATEGORIES_VIEWED
# ---------------------
# data type:int64
# count:    1946
#
# min:      1
# max:      10
#
# mean:     5.383864337101747
# median:   5.0
# mode:     2
#
# variance: 9.265940020660693
# Std Devn: 3.0440006604238268
#
# Skewness: 0.1637969955550979
# Kurtosis: -1.3660223498233819
#
# IQR 25%:  3.0
# IQR 50%:  5.0
# IQR 75%:  8.0

# %%
#Plotting the histogram
plt.figure(figsize=(8,4))
data['PRODUCT_CATEGORIES_VIEWED'].hist()
plt.xlabel('PRODUCT_CATEGORIES_VIEWED')
plt.ylabel('PRODUCT_CATEGORIES_VIEWED')

plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting the kde plot
sns.kdeplot(data['PRODUCT_CATEGORIES_VIEWED'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a Box-plot
plt.figure(figsize=(8,6))
plt.boxplot(data['PRODUCT_CATEGORIES_VIEWED'])
plt.show()

# %% [markdown]
# **From the analysis, I Infer that the curve is slightly Platkurthic**

# %% [markdown]
# ##### AVG_TIME_PER_SITE_VISIT

# %%
#Descriptive statistics for thhe column Product_categories_viewed
count_value=data['AVG_TIME_PER_SITE_VISIT'].count() #Count of values
min_value= data['AVG_TIME_PER_SITE_VISIT'].min() #Minimum value
max_value=data['AVG_TIME_PER_SITE_VISIT'].max() #Maximum value
mean_value=data['AVG_TIME_PER_SITE_VISIT'].mean() #Mean 
median_value=data['AVG_TIME_PER_SITE_VISIT'].median() #Median
mode_value=data['AVG_TIME_PER_SITE_VISIT'].mode() #Mode
variance_val=data['AVG_TIME_PER_SITE_VISIT'].var() #Variance
std_value=data['AVG_TIME_PER_SITE_VISIT'].std() #Standard Deviation
q25_value=data['AVG_TIME_PER_SITE_VISIT'].quantile(0.25) #IQR
q50_value=data['AVG_TIME_PER_SITE_VISIT'].quantile(0.50)
q75_value=data['AVG_TIME_PER_SITE_VISIT'].quantile(0.75)
data_type=data['AVG_TIME_PER_SITE_VISIT'].dtype #Data type
skew_value=data['AVG_TIME_PER_SITE_VISIT'].skew() #Skewness
kurt_value=data['AVG_TIME_PER_SITE_VISIT'].kurt() #Kurthosis

#Printing all the required values useful to understand the data
print(f'''
AVG_TIME_PER_SITE_VISIT
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
# AVG_TIME_PER_SITE_VISIT
# ---------------------
# data type:float64
# count:    1946
#
# min:      33.4
# max:      564.2
#
# mean:     150.55657759506653
# median:   145.6
# mode:     86.4
#
# variance: 2445.0235685381886
# Std Devn: 49.44717958122777
#
# Skewness: 1.200282504678305
# Kurtosis: 4.07918162901113
#
# IQR 25%:  114.4
# IQR 50%:  145.6
# IQR 75%:  173.775

# %%
#Plotting the Histogram
plt.figure(figsize=(8,4))
data['AVG_TIME_PER_SITE_VISIT'].hist()
plt.xlabel('AVG_TIME_PER_SITE_VISIT')


plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting the kde
sns.kdeplot(data['AVG_TIME_PER_SITE_VISIT'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting the Box Plot
plt.figure(figsize=(8,6))
plt.boxplot(data['AVG_TIME_PER_SITE_VISIT'])
plt.show()

# %% [markdown]
# **From the above analysis the data distribution is right skewed with any outlier in the upper limit**

# %% [markdown]
# ##### CANCELLATIONS_AFTER_NOON

# %%
#Descriptive statistics for thhe column Product_categories_viewed
count_value=data['CANCELLATIONS_AFTER_NOON'].count() #Count of values
min_value= data['CANCELLATIONS_AFTER_NOON'].min() #Minimum value
max_value=data['CANCELLATIONS_AFTER_NOON'].max() #Maximum value
mean_value=data['CANCELLATIONS_AFTER_NOON'].mean() #Mean
median_value=data['CANCELLATIONS_AFTER_NOON'].median() #Median
mode_value=data['CANCELLATIONS_AFTER_NOON'].mode() #Mode
variance_val=data['CANCELLATIONS_AFTER_NOON'].var() #Variance
std_value=data['CANCELLATIONS_AFTER_NOON'].std() #Standard deviation
q25_value=data['CANCELLATIONS_AFTER_NOON'].quantile(0.25) #IQR
q50_value=data['CANCELLATIONS_AFTER_NOON'].quantile(0.50)
q75_value=data['CANCELLATIONS_AFTER_NOON'].quantile(0.75)
data_type=data['CANCELLATIONS_AFTER_NOON'].dtype #Datatypes
skew_value=data['CANCELLATIONS_AFTER_NOON'].skew() #Skewness
kurt_value=data['CANCELLATIONS_AFTER_NOON'].kurt() #Kurthosis


#Printing all the required data useful for our understanding
print(f'''
CANCELLATIONS_AFTER_NOON
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
# CANCELLATIONS_AFTER_NOON
# ---------------------
# data type:int64
# count:    1946
#
# min:      0
# max:      13
#
# mean:     1.5709146968139773
# median:   1.0
# mode:     1
#
# variance: 2.5957397284522896
# Std Devn: 1.6111299539305604
#
# Skewness: 1.4366289041414948
# Kurtosis: 3.0005102744135743
#
# IQR 25%:  0.0
# IQR 50%:  1.0
# IQR 75%:  2.0

# %%
#Plotting a Histogram
plt.figure(figsize=(8,4))
data['CANCELLATIONS_AFTER_NOON'].hist()
plt.xlabel('CANCELLATIONS_AFTER_NOON')
plt.ylabel('CANCELLATIONS_AFTER_NOON')

plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a kde
sns.kdeplot(data['CANCELLATIONS_AFTER_NOON'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting the box plot
plt.figure(figsize=(8,6))
plt.boxplot(data['CANCELLATIONS_AFTER_NOON'])
plt.show()

# %% [markdown]
# **From the above EDA, I infer that the data is right skewed with skewness is 1.43 and kurthosis equal to 3.**

# %% [markdown]
# ##### PC_LOGINS

# %%
#Descriptive statistics for thhe column pc_logins
count_value=data['PC_LOGINS'].count() #Count of value
min_value= data['PC_LOGINS'].min() #Minimum value
max_value=data['PC_LOGINS'].max() #Maximum Value
mean_value=data['PC_LOGINS'].mean() #Mean
median_value=data['PC_LOGINS'].median() #Median
mode_value=data['PC_LOGINS'].mode() #Mode
variance_val=data['PC_LOGINS'].var() #Variance
std_value=data['PC_LOGINS'].std() #Standard Deviation
q25_value=data['PC_LOGINS'].quantile(0.25) #IQR
q50_value=data['PC_LOGINS'].quantile(0.50)
q75_value=data['PC_LOGINS'].quantile(0.75)
data_type=data['PC_LOGINS'].dtype #Data type
skew_value=data['PC_LOGINS'].skew() #Skewness
kurt_value=data['PC_LOGINS'].kurt() #Kurthosis

#Printing all the required statistical data
print(f'''
      PC_LOGINS
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
#       PC_LOGINS
# ---------------------
# data type:int64
# count:    1946
#
# min:      4
# max:      7
#
# mean:     5.515930113052415
# median:   6.0
# mode:     6
#
# variance: 0.3372782347019924
# Std Devn: 0.5807566053881715
#
# Skewness: -0.03838431609304645
# Kurtosis: -0.5267607947832658
#
# IQR 25%:  5.0
# IQR 50%:  6.0
# IQR 75%:  6.0

# %%
#Printing the Histogram
plt.figure(figsize=(8,6))
data['PC_LOGINS'].hist(bins=4)
plt.xlabel('PC_LOGINS')


plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Printing the kde plot
sns.kdeplot(data['PC_LOGINS'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Printing the box plot
plt.figure(figsize=(8,6))
plt.boxplot(data['PC_LOGINS'])
plt.show()

# %% [markdown]
# **Unable to draw any conclusion of this**

# %% [markdown]
# ##### MOBILE_LOGINS

# %%
#Descriptive statistics for thhe column Mobile_logins
count_value=data['MOBILE_LOGINS'].count() #Number of value
min_value= data['MOBILE_LOGINS'].min() #Minimun value
max_value=data['MOBILE_LOGINS'].max() #Maximum value
mean_value=data['MOBILE_LOGINS'].mean() #Mean
median_value=data['MOBILE_LOGINS'].median() #Median
mode_value=data['MOBILE_LOGINS'].mode() #Mode
variance_val=data['MOBILE_LOGINS'].var() #Variance
std_value=data['MOBILE_LOGINS'].std() #Standard Deviation
q25_value=data['MOBILE_LOGINS'].quantile(0.25) #IQR
q50_value=data['MOBILE_LOGINS'].quantile(0.50)
q75_value=data['MOBILE_LOGINS'].quantile(0.75)
data_type=data['MOBILE_LOGINS'].dtype #Data type
skew_value=data['MOBILE_LOGINS'].skew() #Skewness
kurt_value=data['MOBILE_LOGINS'].kurt() #Kurthosis

#Printing all the required statistical data
print(f'''
    MOBILE_LOGINS
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
#     MOBILE_LOGINS
# ---------------------
# data type:int64
# count:    1946
#
# min:      0
# max:      3
#
# mean:     1.4763617677286742
# median:   1.0
# mode:     1
#
# variance: 0.2783612551750748
# Std Devn: 0.52759952158344
#
# Skewness: 0.05228501941350616
# Kurtosis: -1.2659958037734989
#
# IQR 25%:  1.0
# IQR 50%:  1.0
# IQR 75%:  2.0

# %%
#Plotting a Histogram
plt.figure(figsize=(8,6))
data['MOBILE_LOGINS'].hist(bins=4)
plt.xlabel('MOBILE_LOGINS')
plt.ylabel('MOBILE_LOGINS')

plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a kde
sns.kdeplot(data['MOBILE_LOGINS'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a boxplot
plt.figure(figsize=(8,6))
plt.boxplot(data['MOBILE_LOGINS'])
plt.show()

# %% [markdown]
# **Unable to draw any conclusions out of it**

# %% [markdown]
# ##### WEEKLY_PLAN

# %%
#Descriptive statistics for thhe column weekly_plan
count_value=data['WEEKLY_PLAN'].count() #Counting the number of values
min_value= data['WEEKLY_PLAN'].min() #Minimum value
max_value=data['WEEKLY_PLAN'].max() #Maximum value
mean_value=data['WEEKLY_PLAN'].mean() #Mean
median_value=data['WEEKLY_PLAN'].median() #Median
mode_value=data['WEEKLY_PLAN'].mode() #Mode
variance_val=data['WEEKLY_PLAN'].var()#Variance
std_value=data['WEEKLY_PLAN'].std()#standard deviation
q25_value=data['WEEKLY_PLAN'].quantile(0.25) #IQR
q50_value=data['WEEKLY_PLAN'].quantile(0.50)
q75_value=data['WEEKLY_PLAN'].quantile(0.75)
data_type=data['WEEKLY_PLAN'].dtype #Data type
skew_value=data['WEEKLY_PLAN'].skew() #skewness
kurt_value=data['WEEKLY_PLAN'].kurt() #Kurthosis

#Printing all the required data useful fo perform statistical study
print(f'''
    WEEKLY_PLAN
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
#     WEEKLY_PLAN
# ---------------------
# data type:int64
# count:    1946
#
# min:      0
# max:      52
#
# mean:     11.329907502569373
# median:   7.0
# mode:     0
#
# variance: 184.23454981149007
# Std Devn: 13.573302833558605
#
# Skewness: 1.5386017097649387
# Kurtosis: 1.4531990064565927
#
# IQR 25%:  1.0
# IQR 50%:  7.0
# IQR 75%:  13.0

# %%
#Plotting a histogram
plt.figure(figsize=(8,4))
data['WEEKLY_PLAN'].hist()
plt.xlabel('WEEKLY_PLAN')
plt.ylabel('WEEKLY_PLAN')

plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a kde
sns.kdeplot(data['WEEKLY_PLAN'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a box plot
plt.figure(figsize=(8,6))
plt.boxplot(data['WEEKLY_PLAN'])
plt.show()

# %% [markdown]
# **There are many outliers which are lying at upper limit of the data set**

# %% [markdown]
# ##### LATE_DELIVERIES

# %%
#Descriptive statistics for thhe column Late_delivery
count_value=data['LATE_DELIVERIES'].count() #count of value
min_value= data['LATE_DELIVERIES'].min() #minimun values
max_value=data['LATE_DELIVERIES'].max() #maximum value
mean_value=data['LATE_DELIVERIES'].mean() #mean
median_value=data['LATE_DELIVERIES'].median() #median
mode_value=data['LATE_DELIVERIES'].mode() #mode
variance_val=data['LATE_DELIVERIES'].var() #variance
std_value=data['LATE_DELIVERIES'].std() #standard deviation
q25_value=data['LATE_DELIVERIES'].quantile(0.25) #IQR
q50_value=data['LATE_DELIVERIES'].quantile(0.50)
q75_value=data['LATE_DELIVERIES'].quantile(0.75)
data_type=data['LATE_DELIVERIES'].dtype #Data type
skew_value=data['LATE_DELIVERIES'].skew() #Skewness
kurt_value=data['LATE_DELIVERIES'].kurt() #Kurtosis

#Printing all the required statistical data
print(f'''
    LATE_DELIVERIES
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
#     LATE_DELIVERIES
# ---------------------
# data type:int64
# count:    1946
#
# min:      0
# max:      18
#
# mean:     2.05344295991778
# median:   0.0
# mode:     0
#
# variance: 14.356011276179578
# Std Devn: 3.788932735768686
#
# Skewness: 1.7096713521746982
# Kurtosis: 1.8942354709101754
#
# IQR 25%:  0.0
# IQR 50%:  0.0
# IQR 75%:  3.0

# %%
#Plotting a histogram
plt.figure(figsize=(8,4))
data['LATE_DELIVERIES'].hist()
plt.xlabel('LATE_DELIVERIES')
plt.ylabel('LATE_DELIVERIES')

plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a kde plot
sns.kdeplot(data['LATE_DELIVERIES'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a box plot
plt.figure(figsize=(8,6))
plt.boxplot(data['LATE_DELIVERIES'])
plt.show()

# %% [markdown]
# **Many Outliers at the upper limit of the data**

# %% [markdown]
# ##### AVG_PREP_VID_TIME

# %%
#Descriptive statistics for thhe column Avg_prep_vid_time
count_value=data['AVG_PREP_VID_TIME'].count() #COunting the number of values
min_value= data['AVG_PREP_VID_TIME'].min() #Minimum value
max_value=data['AVG_PREP_VID_TIME'].max() #Maximum value
mean_value=data['AVG_PREP_VID_TIME'].mean() #Mean
median_value=data['AVG_PREP_VID_TIME'].median() #Medin
mode_value=data['AVG_PREP_VID_TIME'].mode() #Mode
variance_val=data['AVG_PREP_VID_TIME'].var() #VAriance
std_value=data['AVG_PREP_VID_TIME'].std() #std
q25_value=data['AVG_PREP_VID_TIME'].quantile(0.25) #IQR
q50_value=data['AVG_PREP_VID_TIME'].quantile(0.50)
q75_value=data['AVG_PREP_VID_TIME'].quantile(0.75)
data_type=data['AVG_PREP_VID_TIME'].dtype #data type
skew_value=data['AVG_PREP_VID_TIME'].skew() #skewness
kurt_value=data['AVG_PREP_VID_TIME'].kurt() #Kurthosis

#Printing all the required statistical data
print(f'''
 AVG_PREP_VID_TIME
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
#  AVG_PREP_VID_TIME
# ---------------------
# data type:float64
# count:    1946
#
# min:      10.33
# max:      1645.6
#
# mean:     99.60465056526209
# median:   94.16
# mode:     48.0
#
# variance: 3886.494553939525
# Std Devn: 62.34175610246735
#
# Skewness: 9.639387888172601
# Kurtosis: 203.9999436399102
#
# IQR 25%:  72.0
# IQR 50%:  94.16
# IQR 75%:  117.2875

# %%
#Plotting a histogram
plt.figure(figsize=(8,4))
data['AVG_PREP_VID_TIME'].hist()
plt.xlabel('AVG_PREP_VID_TIME')
plt.ylabel('AVG_PREP_VID_TIME')

plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a kde plot
sns.kdeplot(data['AVG_PREP_VID_TIME'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a boxplot
plt.figure(figsize=(8,6))
plt.boxplot(data['AVG_PREP_VID_TIME'])
plt.show()

# %% [markdown]
# **The data not normal and many outlier at the upper limit which is making disturbing the uniformity of the data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1946 entries, 0 to 1945
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   REVENUE                               1946 non-null   float64
#  1   NAME                                  1946 non-null   object
#  2   EMAIL                                 1946 non-null   object
#  3   FIRST_NAME                            1946 non-null   object
#  4   FAMILY_NAME                           1946 non-null   object
#  5   TOTAL_MEALS_ORDERED                   1946 non-null   int64
#  6   UNIQUE_MEALS_PURCH                    1946 non-null   int64
#  7   CONTACTS_W_CUSTOMER_SERVICE           1946 non-null   int64
#  8   PRODUCT_CATEGORIES_VIEWED             1946 non-null   int64
#  9   AVG_TIME_PER_SITE_VISIT               1946 non-null   float64
#  10  CANCELLATIONS_AFTER_NOON              1946 non-null   int64
# ...

# %% [markdown]
# ##### AVG_NUM_0F_MEAL_ORDERED_PER_CUSTOMER

# %%
#Descriptive statistics for thhe column Avg_num_of_meal_ordered_per_customer
count_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].count() #count of values
min_value= data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].min() #Minimum value
max_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].max() #MAximum value
mean_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].mean() #MEan
median_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].median() #Median
mode_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].mode() #Mode
variance_val=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].var() #variance
std_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].std() #standard deviation
q25_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].quantile(0.25) #IQR
q50_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].quantile(0.50)
q75_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].quantile(0.75)
data_type=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].dtype #Data type
skew_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].skew() #skewness
kurt_value=data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].kurt() #Kurthosis

#Printing all the required statistical data
print(f'''
AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
# AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER
# ---------------------
# data type:int64
# count:    1946
#
# min:      1
# max:      11
#
# mean:     4.437307297019527
# median:   4.0
# mode:     4
#
# variance: 2.401466061818216
# Std Devn: 1.5496664356622738
#
# Skewness: 0.7039951965132559
# Kurtosis: 0.9322870310741806
#
# IQR 25%:  3.0
# IQR 50%:  4.0
# IQR 75%:  5.0

# %%
#Plotting a histogram
plt.figure(figsize=(8,4))
data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'].hist()
plt.xlabel('AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER')

plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a kde plot
sns.kdeplot(data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#PLotting a box plot
plt.figure(figsize=(8,6))
plt.boxplot(data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'])
plt.show()

# %% [markdown]
# **Data looks symnentric but does conclude anything from it**

# %% [markdown]
# ##### AVG_MEAN_RATING

# %%
#Descriptive statistics for thhe column Avg_mean_rating
count_value=data['AVG_MEAN_RATING'].count() #Count of values
min_value= data['AVG_MEAN_RATING'].min() #Minimum value
max_value=data['AVG_MEAN_RATING'].max() #Maximum value
mean_value=data['AVG_MEAN_RATING'].mean() #Mean
median_value=data['AVG_MEAN_RATING'].median() #Median
mode_value=data['AVG_MEAN_RATING'].mode() #Mode
variance_val=data['AVG_MEAN_RATING'].var() #Variance
std_value=data['AVG_MEAN_RATING'].std() #standard deviation
q25_value=data['AVG_MEAN_RATING'].quantile(0.25) #IQR
q50_value=data['AVG_MEAN_RATING'].quantile(0.50)
q75_value=data['AVG_MEAN_RATING'].quantile(0.75)
data_type=data['AVG_MEAN_RATING'].dtype #Data type
skew_value=data['AVG_MEAN_RATING'].skew() #Skewness
kurt_value=data['AVG_MEAN_RATING'].kurt() #Kurtosis

#Printing all the required statistical data
print(f'''
AVG_MEAN_RATING
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
# AVG_MEAN_RATING
# ---------------------
# data type:float64
# count:    1946
#
# min:      1.3157894736842104
# max:      5.0
#
# mean:     3.554795261535153
# median:   3.4210526315789473
# mode:     3.4210526315789473
#
# variance: 0.3772144089931038
# Std Devn: 0.6141778317336957
#
# Skewness: -0.1134114063059372
# Kurtosis: -0.17924100590523961
#
# IQR 25%:  3.1578947368421053
# IQR 50%:  3.4210526315789473
# IQR 75%:  3.947368421052632

# %%
#Plotting a histogram
plt.figure(figsize=(8,4))
data['AVG_MEAN_RATING'].hist()
plt.xlabel('AVG_MEAN_RATING')
plt.ylabel('AVG_MEAN_RATING')

plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plottting a kde
sns.kdeplot(data['AVG_MEAN_RATING'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a bar plot
plt.figure(figsize=(8,6))
plt.boxplot(data['AVG_MEAN_RATING'])
plt.show()

# %% [markdown]
# **From the analysis, I infer that the data is left skewed**

# %% [markdown]
# ##### TOTAL_PHOTOS_VIEWED

# %%
#Descriptive statistics for thhe column Total_photos_viewed
count_value=data['TOTAL_PHOTOS_VIEWED'].count() #Count of values
min_value= data['TOTAL_PHOTOS_VIEWED'].min() #Minimum value
max_value=data['TOTAL_PHOTOS_VIEWED'].max() #Maximum value
mean_value=data['TOTAL_PHOTOS_VIEWED'].mean() #Mean
median_value=data['TOTAL_PHOTOS_VIEWED'].median() #Median
mode_value=data['TOTAL_PHOTOS_VIEWED'].mode() #Mode
variance_val=data['TOTAL_PHOTOS_VIEWED'].var() #Variance
std_value=data['TOTAL_PHOTOS_VIEWED'].std() #Standard Deviation
q25_value=data['TOTAL_PHOTOS_VIEWED'].quantile(0.25) #IQR
q50_value=data['TOTAL_PHOTOS_VIEWED'].quantile(0.50)
q75_value=data['TOTAL_PHOTOS_VIEWED'].quantile(0.75)
data_type=data['TOTAL_PHOTOS_VIEWED'].dtype #Data type
skew_value=data['TOTAL_PHOTOS_VIEWED'].skew() #Skewness
kurt_value=data['TOTAL_PHOTOS_VIEWED'].kurt() #Kurthosis

#Printing all the required statistical data
print(f'''
TOTAL_PHOTOS_VIEWED
---------------------
data type:{data_type}
count:    {count_value}

min:      {min_value}
max:      {max_value}

mean:     {mean_value}
median:   {median_value}
mode:     {mode_value[0]}

variance: {variance_val}
Std Devn: {std_value}

Skewness: {skew_value}
Kurtosis: {kurt_value}

IQR 25%:  {q25_value}
IQR 50%:  {q50_value}
IQR 75%:  {q75_value}
''')
# Out:
# TOTAL_PHOTOS_VIEWED
# ---------------------
# data type:int64
# count:    1946
#
# min:      1
# max:      1600
#
# mean:     113.15159301130524
# median:   17.0
# mode:     12
#
# variance: 31382.931763527828
# Std Devn: 177.1522841047437
#
# Skewness: 2.604684794001246
# Kurtosis: 9.394310446510689
#
# IQR 25%:  10.0
# IQR 50%:  17.0
# IQR 75%:  174.0

# %%
#Plotting a Histogram
plt.figure(figsize=(8,4))
data['TOTAL_PHOTOS_VIEWED'].hist()
plt.xlabel('TOTAL_PHOTOS_VIEWED')
plt.ylabel('TOTAL_PHOTOS_VIEWED')

plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a kde
sns.kdeplot(data['TOTAL_PHOTOS_VIEWED'])
plt.axvline(mean_value,label='MEAN',color='red')
plt.axvline(median_value,label='MEDIAN',color='blue')
plt.axvline(mode_value[0],label='MODE',color='green')
plt.legend()
plt.show()

# %%
#Plotting a box plot
plt.figure(figsize=(8,6))
plt.boxplot(data['TOTAL_PHOTOS_VIEWED'])
plt.show()

# %% [markdown]
# **The distribution of data is right skewed and many outlier is effeting the distribution**

# %% [markdown]
# #### CATEGORICAL VARIABLES

# %% [markdown]
# ##### Name

# %%
#Checking number of unique values
data['NAME'].nunique()
# Out:
# 1946

# %% [markdown]
# **Checked wheather there are any duplicated or any customer is repeating**

# %% [markdown]
# ##### Family_name

# %%
#Checking number of unique values
data['FAMILY_NAME'].nunique()
# Out:
# 1104

# %%
#plotting a bar graph to vizualize
data['FAMILY_NAME'].value_counts()[:40].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Analyzing from the Family data is useless**

# %% [markdown]
# ##### Family_name

# %%
#Checking the number of values
data['FIRST_NAME'].nunique()
# Out:
# 1442

# %%
#plotting a bar graph to vizualize
data['FIRST_NAME'].value_counts()[:40].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Email_Id

# %%
#Checking the unique values
data['EMAIL'].nunique()
# Out:
# 1946

# %% [markdown]
# ### Bivariate Analysis

# %%
#Pritinting the mumerical columns in the dataset 
data_num = data.select_dtypes(include=np.number)
data_num.columns
# Out:
# Index(['REVENUE', 'TOTAL_MEALS_ORDERED', 'UNIQUE_MEALS_PURCH',
#        'CONTACTS_W_CUSTOMER_SERVICE', 'PRODUCT_CATEGORIES_VIEWED',
#        'AVG_TIME_PER_SITE_VISIT', 'CANCELLATIONS_AFTER_NOON', 'PC_LOGINS',
#        'MOBILE_LOGINS', 'WEEKLY_PLAN', 'LATE_DELIVERIES', 'AVG_PREP_VID_TIME',
#        'AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER', 'AVG_MEAN_RATING',
#        'TOTAL_PHOTOS_VIEWED'],
#       dtype='object')

# %% [markdown]
# **Displaying the number of numerical data types are present**

# %% [markdown]
# #### REVENUE v/s TOTAL_MEALS_ORDERED

# %%
#Plotting a Scatter plot
plt.scatter(data['REVENUE'],data['TOTAL_MEALS_ORDERED'])

# %% [markdown]
# **The plot looks like having a strong positive correlation**

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['TOTAL_MEALS_ORDERED'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **The maximum values lies between 1500-2000 and total orders less than 100**

# %% [markdown]
# #### REVENUE v/s UNIQUE_MEALS_PURCH

# %% [markdown]
# **This scater plot stating that this relationship is neutral**

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['UNIQUE_MEALS_PURCH'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Maximum values occurs between 1500-4000 for revenue and 3-8 for unique_meals_purchase**

# %% [markdown]
# #### REVENUE v/s CONTACTS_W_CUSTOMER_SERVICE

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['CONTACTS_W_CUSTOMER_SERVICE'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **From the graph more values lies between 1500-2000 in revenue and the customer services is equally distributed from 2.5 to 10 which seams that many were using it**

# %% [markdown]
# #### REVENUE v/s PRODUCT_CATEGORIES_VIEWED

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['PRODUCT_CATEGORIES_VIEWED'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Unable to draw any conclusions about correlation which is looking like neutral or no relationship**

# %% [markdown]
# #### REVENUE v/s AVG_TIME_PER_SITE_VISIT

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['AVG_TIME_PER_SITE_VISIT'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **The maximum revenue lies between 500 to 5000 and their is positive correlation between the both the columns an daverage time spent in in visit is citing as 50 to 250**

# %% [markdown]
# #### REVENUE v/s CANCELLATIONS_AFTER_NOON

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['CANCELLATIONS_AFTER_NOON'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Unable to find any correlation between them**

# %% [markdown]
# #### REVENUE v/s PC_LOGINS

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['PC_LOGINS'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Unable to come to any conclusions**

# %% [markdown]
# #### REVENUE v/s MOBILE_LOGINS

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['MOBILE_LOGINS'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Unable to come to any conclusions**

# %% [markdown]
# #### REVENUE v/s WEEKLY_PLAN

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['WEEKLY_PLAN'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Unable to come to any conclusions**

# %% [markdown]
# #### REVENUE v/s LATE_DELIVERIES

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['LATE_DELIVERIES'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Unable to come to any conclusions**

# %% [markdown]
# #### REVENUE v/s AVG_PREP_VID_TIME

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['AVG_PREP_VID_TIME'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **There no strong relationship**

# %% [markdown]
# #### REVENUE v/s AVG_NUM_0F_MEAL_ORDERED_PER_CUSTOMER

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Unable to come to any conclusions**

# %% [markdown]
# #### REVENUE v/s AVG_MEAN_RATING

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['AVG_MEAN_RATING'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Unable to come to any conclusions**

# %% [markdown]
# #### REVENUE v/s TOTAL_PHOTOS_VIEWED

# %%
#Plotting a Jointplot
plt.figure(figsize=(7,5))
sns.jointplot(data['REVENUE'], data['TOTAL_PHOTOS_VIEWED'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **But the maximum values is lying almost equal to zero which is making to conclude that is very less correlation**

# %% [markdown]
# ### Multi-variate Analysis

# %%
data.corr()
# Out:
#                                        REVENUE  TOTAL_MEALS_ORDERED  \
# REVENUE                               1.000000             0.600489
# TOTAL_MEALS_ORDERED                   0.600489             1.000000
# UNIQUE_MEALS_PURCH                    0.101659            -0.038519
# CONTACTS_W_CUSTOMER_SERVICE           0.174303            -0.066576
# PRODUCT_CATEGORIES_VIEWED             0.034492             0.004875
# AVG_TIME_PER_SITE_VISIT               0.643580             0.494509
# CANCELLATIONS_AFTER_NOON              0.003420             0.008605
# PC_LOGINS                             0.016118            -0.007261
# MOBILE_LOGINS                         0.073381             0.054885
# WEEKLY_PLAN                           0.009794             0.018344
# LATE_DELIVERIES                      -0.020114            -0.023130
# AVG_PREP_VID_TIME                     0.144572             0.149481
# AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER  0.435068             0.358680
# ...

# %%
# plot the heat map
# corr(): give the correlation matrix
# annot: prints the correlation values in the chart
# annot_kws: sets the font size of the annotation
sns.heatmap(data.corr()[np.abs(data.corr()) > 0.25], annot = True,linewidths=0.3, annot_kws = {"size": 11})

# rotate the y-axis labels
# set text size using 'fontsize'
plt.yticks(rotation = 'horizontal', fontsize = 15)
plt.xticks(rotation = 'vertical',fontsize = 15)

# display the plot
plt.show()

# %% [markdown]
# **It is observed that columns total_meals_ordered, Avg_time_per_site_visit, Avg_num_of_meal_ordered_per_customer, Total_photos_viewed has the strong positive correlation.**

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Dealing with Categorical variable

# %% [markdown]
# #### Categorizing the email_is with respect to their use

# %%
# define function to categorize domains
def categorize_domain(domain):
    personal_domains = ['gmail.com', 'yahoo.com', 'protonmail.com']
    junk_domains = ['me.com', 'aol.com', 'hotmail.com', 'live.com', 'msn.com', 'passport.com']
    if domain in personal_domains:
        return 'PERSONAL'
    elif domain in junk_domains:
        return 'JUNK'
    else: 
        return 'PROFESSIONAL'

# extract domain name from email addresses
data['SS_EMAIL_CATEGORY'] = data['EMAIL'].apply(lambda x: x.split('@')[1])

# apply domain categorization function
data['SS_EMAIL_CATEGORY'] = data['SS_EMAIL_CATEGORY'].apply(categorize_domain)

# print result
data.head()
# Out:
#    REVENUE                    NAME                             EMAIL  \
# 0   4920.0       Steffon Baratheon       steffon.baratheon@yahoo.com
# 1   6150.0          Harlon Greyjoy           harlon.greyjoy@visa.com
# 2   3435.0                 Monster            monster@protonmail.com
# 3   3330.0  Damon Lannister (lord)  damon.lannister.(lord)@yahoo.com
# 4   3427.5      Raynald Westerling        raynald.westerling@jnj.com
#
#   FIRST_NAME FAMILY_NAME  TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  \
# 0    Steffon   Baratheon                  493                   9
# 1     Harlon     Greyjoy                  361                   9
# 2    Monster     Monster                  278                   6
# 3      Damon  Lannister                   269                   8
# 4    Raynald  Westerling                  276                   7
#
#    CONTACTS_W_CUSTOMER_SERVICE  PRODUCT_CATEGORIES_VIEWED  \
# 0                            1                         10
# ...

# %% [markdown]
# **Segregating the data as personal, professional and junk**

# %% [markdown]
# #### Using one hot encoder making categorical data into Numerical data

# %%
encoded_data = pd.get_dummies(data['SS_EMAIL_CATEGORY'], prefix='SS_EMAIL_CATEGORY',drop_first=True)

# Add the one-hot encoded columns to the original DataFrame
data = pd.concat([data, encoded_data], axis=1)
data.head(5)
# Out:
#    REVENUE                    NAME                             EMAIL  \
# 0   4920.0       Steffon Baratheon       steffon.baratheon@yahoo.com
# 1   6150.0          Harlon Greyjoy           harlon.greyjoy@visa.com
# 2   3435.0                 Monster            monster@protonmail.com
# 3   3330.0  Damon Lannister (lord)  damon.lannister.(lord)@yahoo.com
# 4   3427.5      Raynald Westerling        raynald.westerling@jnj.com
#
#   FIRST_NAME FAMILY_NAME  TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  \
# 0    Steffon   Baratheon                  493                   9
# 1     Harlon     Greyjoy                  361                   9
# 2    Monster     Monster                  278                   6
# 3      Damon  Lannister                   269                   8
# 4    Raynald  Westerling                  276                   7
#
#    CONTACTS_W_CUSTOMER_SERVICE  PRODUCT_CATEGORIES_VIEWED  \
# 0                            1                         10
# ...

# %% [markdown]
# **Using one hot encoder (n-1) feature technique making the categorical data into numerical data.**

# %% [markdown]
# **Plotting bar plot to new formed column**

# %%
#Plotting a bar graph
plt.figure(figsize = (8,6))
sns.countplot(data['SS_EMAIL_CATEGORY'])
# Out:
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SS_EMAIL_CATEGORY', ylabel='count'>

# %%
#Plotting a pie diagram
plt.figure(figsize = (8,6))
data['SS_EMAIL_CATEGORY'].value_counts().plot(kind='pie',autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='SS_EMAIL_CATEGORY'>

# %% [markdown]
# **Vizualizing the data about how the customer are categorized**

# %% [markdown]
# ### Outlier treatment

# %% [markdown]
# **As there are many outliers in the data, choosing the path to treat the outlier and distribute the data normal and reducing the skewness and making the curve symnetric.**

# %%
#Displaying the curve
for i in data.select_dtypes(exclude='object').columns:
    plt.figure(figsize=(4,2))
    print('column : ', i)
    sns.distplot(data[i], hist=False)
    plt.show()
# Out:
# column :  REVENUE
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/signet/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# column :  TOTAL_MEALS_ORDERED
# column :  UNIQUE_MEALS_PURCH
# ...

# %%
#Finding the skewness of the data
data.skew()
# Out:
# /var/folders/jl/kz2pln212z99922y98kbdrgm0000gn/T/ipykernel_93305/3053366371.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.skew()
# REVENUE                                 1.626573
# TOTAL_MEALS_ORDERED                     2.006653
# UNIQUE_MEALS_PURCH                      0.566015
# CONTACTS_W_CUSTOMER_SERVICE             0.370833
# PRODUCT_CATEGORIES_VIEWED               0.163797
# AVG_TIME_PER_SITE_VISIT                 1.200283
# CANCELLATIONS_AFTER_NOON                1.436629
# PC_LOGINS                              -0.038384
# MOBILE_LOGINS                           0.052285
# WEEKLY_PLAN                             1.538602
# LATE_DELIVERIES                         1.709671
# AVG_PREP_VID_TIME                       9.639388
# AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER    0.703995
# ...

# %% [markdown]
# #### Logrithmic Transformation

# %% [markdown]
# **Choosing the logrithmic transformation to treat the outliers and make the uniform distribution of data**

# %%
#Making the new features by logarithmic transformation of data.
data['LOG_TOTAL_MEALS_ORDERED']=np.log(data['TOTAL_MEALS_ORDERED']) #Log of TOTAL_MEALS_ORDERED
data['LOG_UNIQUE_MEALS_PURCH']=np.log(data['UNIQUE_MEALS_PURCH']) #Log of UNIQUE_MEALS_PURCH
data['LOG_CONTACTS_W_CUSTOMER_SERVICE']=np.log(data['CONTACTS_W_CUSTOMER_SERVICE']) #Log of CONTACTS_W_CUSTOMER_SERVICE
data['LOG_PRODUCT_CATEGORIES_VIEWED']=np.log(data['PRODUCT_CATEGORIES_VIEWED'])#Log of PRODUCT_CATEGORIES_VIEWED
data['LOG_AVG_TIME_PER_SITE_VISIT']=np.log(data['AVG_TIME_PER_SITE_VISIT']) #Log of AVG_TIME_PER_SITE_VISIT
data['LOG_CANCELLATIONS_AFTER_NOON']=np.log(data['CANCELLATIONS_AFTER_NOON']+0.001)#Log of CANCELLATIONS_AFTER_NOON
data['LOG_PC_LOGINS']=np.log(data['PC_LOGINS']) #Log of PC_LOGINS
data['LOG_WEEKLY_PLAN']=np.log(data['WEEKLY_PLAN']+0.001) #Log of WEEKLY_PLAN
data['LOG_LATE_DELIVERIES']=np.log(data['LATE_DELIVERIES']+0.001)#Log of LATE_DELIVERIES
data['LOG_AVG_PREP_VID_TIME']=np.log(data['AVG_PREP_VID_TIME']) #Log of AVG_PREP_VID_TIME
data['LOG_AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER']=np.log(data['AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER'])#Log of AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER
data['LOG_AVG_MEAN_RATING']=np.log(data['AVG_MEAN_RATING']) #Log of AVG_MEAN_RATING
data['LOG_TOTAL_PHOTOS_VIEWED']=np.log(data['TOTAL_PHOTOS_VIEWED']) #Log of TOTAL_PHOTOS_VIEWED
data['LOG_REVENUE']=np.log(data['REVENUE']) #Log of revenue

# %%
# x-variables for normal y
x_var = ['TOTAL_MEALS_ORDERED', 'UNIQUE_MEALS_PURCH', 'CONTACTS_W_CUSTOMER_SERVICE',
               'PRODUCT_CATEGORIES_VIEWED', 'AVG_TIME_PER_SITE_VISIT', 'CANCELLATIONS_AFTER_NOON',
               'PC_LOGINS', 'MOBILE_LOGINS', 'WEEKLY_PLAN',
               'LATE_DELIVERIES', 'AVG_PREP_VID_TIME', 'AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER',
               'AVG_MEAN_RATING', 'TOTAL_PHOTOS_VIEWED', 'SS_EMAIL_CATEGORY_PERSONAL',
               'SS_EMAIL_CATEGORY_PROFESSIONAL']

# %%
# x-variables for log y
x_log_var =['LOG_TOTAL_MEALS_ORDERED', 'LOG_UNIQUE_MEALS_PURCH', 'LOG_CONTACTS_W_CUSTOMER_SERVICE',
               'LOG_PRODUCT_CATEGORIES_VIEWED', 'LOG_AVG_TIME_PER_SITE_VISIT', 'LOG_CANCELLATIONS_AFTER_NOON',
               'LOG_PC_LOGINS', 'MOBILE_LOGINS', 'LOG_WEEKLY_PLAN',
               'LOG_LATE_DELIVERIES', 'LOG_AVG_PREP_VID_TIME', 'LOG_AVG_NUM_OF_MEAL_ORDERED_PER_CUSTOMER',
               'LOG_AVG_MEAN_RATING', 'LOG_TOTAL_PHOTOS_VIEWED', 'SS_EMAIL_CATEGORY_PERSONAL',
               'SS_EMAIL_CATEGORY_PROFESSIONAL']

# %%
data.head(2)
# Out:
#    REVENUE               NAME                        EMAIL FIRST_NAME  \
# 0   4920.0  Steffon Baratheon  steffon.baratheon@yahoo.com    Steffon
# 1   6150.0     Harlon Greyjoy      harlon.greyjoy@visa.com     Harlon
#
#   FAMILY_NAME  TOTAL_MEALS_ORDERED  UNIQUE_MEALS_PURCH  \
# 0   Baratheon                  493                   9
# 1     Greyjoy                  361                   9
#
#    CONTACTS_W_CUSTOMER_SERVICE  PRODUCT_CATEGORIES_VIEWED  \
# 0                            1                         10
# 1                            1                          6
#
#    AVG_TIME_PER_SITE_VISIT  ...  LOG_AVG_TIME_PER_SITE_VISIT  \
# 0                    265.6  ...                     5.581991
# 1                    247.0  ...                     5.509388
#
#    LOG_CANCELLATIONS_AFTER_NOON  LOG_PC_LOGINS  LOG_WEEKLY_PLAN  \
# 0                      1.609638       1.609438        -6.907755
# 1                      0.693647       1.609438        -6.907755
#
# ...

# %%
data.skew()
# Out:
# /var/folders/jl/kz2pln212z99922y98kbdrgm0000gn/T/ipykernel_93305/1188251951.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.skew()
# REVENUE                                     1.626573
# TOTAL_MEALS_ORDERED                         2.006653
# UNIQUE_MEALS_PURCH                          0.566015
# CONTACTS_W_CUSTOMER_SERVICE                 0.370833
# PRODUCT_CATEGORIES_VIEWED                   0.163797
# AVG_TIME_PER_SITE_VISIT                     1.200283
# CANCELLATIONS_AFTER_NOON                    1.436629
# PC_LOGINS                                  -0.038384
# MOBILE_LOGINS                               0.052285
# WEEKLY_PLAN                                 1.538602
# LATE_DELIVERIES                             1.709671
# AVG_PREP_VID_TIME                           9.639388
# ...

# %% [markdown]
# ## Regression Model Development

# %% [markdown]
# **Aim - Our Model must have Training test score and Testing test score greater than or equal to 0.5 and. gap to be less than or equal to 0.05.**

# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# #### Orginal data

# %%
# preparing for scikit-learn

# Preparing a DataFrame based the the analysis above
x_data = data.loc[ : , x_var] #Storing x_variables
log_x_data=data.loc[:,x_log_var] #storing Tranformed variables


# preparing response variable
y_data      = data.loc[ : , 'REVENUE'] #Storing y variables
log_y_data  = data.loc[ : , 'LOG_REVENUE'] #Storing log y variables


#################################
## setting up train-test split ##
#################################
x_train, x_test, y_train, y_test = train_test_split(
            x_data, # x-variables 
            y_data, # y-variable  
            test_size    = 0.25,
            random_state = 219)

# %%
# Setting a model name
model_name = "Linear Regression"


# INSTANTIATING a model object - CHANGE THIS AS NEEDED
model = sklearn.linear_model.LinearRegression()


# FITTING to the training data
model_fit = model.fit(x_train, y_train)


# PREDICTING on new data
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)


# displaying results
print('Training Score :', model_train_score)
print('Testing Score  :', model_test_score)
print('Train-Test Gap :', model_gap)
# Out:
# Training Score : 0.6217
# Testing Score  : 0.6362
# Train-Test Gap : 0.0145

# %% [markdown]
# **This Model gave us good results - So accepting this Model**

# %% [markdown]
# #### Transformed Data

# %%
# setting up train-test split
x_train, x_test, y_train, y_test = train_test_split(
            log_x_data, # x-variables (can change this)
            log_y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# Setting a model name
model_name = "Linear Regression"


# INSTANTIATING a model object - CHANGE THIS AS NEEDED
model = sklearn.linear_model.LinearRegression()


# FITTING to the training data
model_fit = model.fit(x_train, y_train)


# PREDICTING on new data
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)


# displaying results
print('Training Score :', model_train_score)
print('Testing Score  :', model_test_score)
print('Train-Test Gap :', model_gap)
# Out:
# Training Score : 0.6799
# Testing Score  : 0.6811
# Train-Test Gap : 0.0012

# %% [markdown]
# **This model also gave us our expected result - So accepting this Model**

# %% [markdown]
# ### Lasso Regression Model

# %% [markdown]
# #### Orginal Data

# %%
# setting up train-test split
x_train, x_test, y_train, y_test = train_test_split(
            x_data, # x-variables (can change this)
            y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# Setting a model name
model_name = "Lasso Regression"


# INSTANTIATING a model object - CHANGE THIS AS NEEDED
model = sklearn.linear_model.Lasso()


# FITTING to the training data
model_fit = model.fit(x_train, y_train)


# PREDICTING on new data
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)


# displaying results
print('Training Score :', model_train_score)
print('Testing Score  :', model_test_score)
print('Train-Test Gap :', model_gap)
# Out:
# Training Score : 0.6217
# Testing Score  : 0.636
# Train-Test Gap : 0.0143

# %% [markdown]
# **This model has also gave us good result - Accepting the model**

# %% [markdown]
# #### Transformed Data

# %%
# setting up train-test split
x_train, x_test, y_train, y_test = train_test_split(
            log_x_data, # x-variables (can change this)
            log_y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# Setting a model name
model_name = "Lasso Regression"


# INSTANTIATING a model object - CHANGE THIS AS NEEDED
model = sklearn.linear_model.Lasso()


# FITTING to the training data
model_fit = model.fit(x_train, y_train)


# PREDICTING on new data
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)


# displaying results
print('Training Score :', model_train_score)
print('Testing Score  :', model_test_score)
print('Train-Test Gap :', model_gap)
# Out:
# Training Score : 0.0
# Testing Score  : -0.0058
# Train-Test Gap : 0.0058

# %% [markdown]
# **This model failed to meet our requirements.**

# %% [markdown]
# ### ARD Regression Model

# %% [markdown]
# #### Original Data

# %%
# setting up train-test split
x_train, x_test, y_train, y_test = train_test_split(
            x_data, # x-variables (can change this)
            y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# Setting a model name
model_name = "ARD Regression"


# INSTANTIATING a model object - CHANGE THIS AS NEEDED
model = sklearn.linear_model.ARDRegression()


# FITTING to the training data
model_fit = model.fit(x_train, y_train)


# PREDICTING on new data
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)


# displaying results
print('Training Score :', model_train_score)
print('Testing Score  :', model_test_score)
print('Train-Test Gap :', model_gap)
# Out:
# Training Score : 0.6211
# Testing Score  : 0.6382
# Train-Test Gap : 0.0171

# %% [markdown]
# **This model has also gave us good result - Accepting the model**

# %% [markdown]
# #### Transformed Data

# %%
# setting up train-test split
x_train, x_test, y_train, y_test = train_test_split(
            log_x_data, # x-variables (can change this)
            log_y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# Setting a model name
model_name = "ARD Regression"


# INSTANTIATING a model object - CHANGE THIS AS NEEDED
model = sklearn.linear_model.ARDRegression()


# FITTING to the training data
model_fit = model.fit(x_train, y_train)


# PREDICTING on new data
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)


# displaying results
print('Training Score :', model_train_score)
print('Testing Score  :', model_test_score)
print('Train-Test Gap :', model_gap)
# Out:
# Training Score : 0.6778
# Testing Score  : 0.6825
# Train-Test Gap : 0.0047

# %% [markdown]
# **This model has also gave us good result - Accepting the model**

# %% [markdown]
# ### Ridge Regression

# %% [markdown]
# #### Orginal Data

# %%
x_train, x_test, y_train, y_test = train_test_split(
            x_data, # x-variables (can change this)
            y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# Setting a model name
model_name = "Ridge Regression"


# INSTANTIATING a model object - CHANGE THIS AS NEEDED
model = sklearn.linear_model.Ridge()


# FITTING to the training data
model_fit = model.fit(x_train, y_train)


# PREDICTING on new data
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)


# displaying results
print('Training Score :', model_train_score)
print('Testing Score  :', model_test_score)
print('Train-Test Gap :', model_gap)
# Out:
# Training Score : 0.6217
# Testing Score  : 0.6362
# Train-Test Gap : 0.0145

# %% [markdown]
# **This model has also gave us good result - Accepting the model**

# %% [markdown]
# #### Transformed Data

# %%
x_train, x_test, y_train, y_test = train_test_split(
            log_x_data, # x-variables (can change this)
            log_y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# INSTANTIATING a model object - CHANGE THIS AS NEEDED
model = sklearn.linear_model.Ridge()


# FITTING to the training data
model_fit = model.fit(x_train, y_train)


# PREDICTING on new data
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)


# displaying results
print('Training Score :', model_train_score)
print('Testing Score  :', model_test_score)
print('Train-Test Gap :', model_gap)
# Out:
# Training Score : 0.6798
# Testing Score  : 0.681
# Train-Test Gap : 0.0012

# %% [markdown]
# **This model has also gave us good result - Accepting the model**

# %% [markdown]
# ### K-Neighbour Regression

# %% [markdown]
# #### Orginal Data

# %%
x_train, x_test, y_train, y_test = train_test_split(
            x_data, # x-variables (can change this)
            y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# INSTANTIATING a KNN model object
knn_reg = KNeighborsRegressor(algorithm = 'auto',
                              n_neighbors = 1)


# FITTING to the training data
knn_fit = knn_reg.fit(x_train, y_train)


# PREDICTING on new data
knn_reg_pred = knn_fit.predict(x_test)


# SCORING the results
print('KNN Training Score:', knn_reg.score(x_train, y_train).round(4))
print('KNN Testing Score :',  knn_reg.score(x_test, y_test).round(4))


# saving scoring data for future use
knn_reg_score_train = knn_reg.score(x_train, y_train).round(4)
knn_reg_score_test  = knn_reg.score(x_test, y_test).round(4)


# displaying and saving the gap between training and testing
print('KNN Train-Test Gap:', abs(knn_reg_score_train - knn_reg_score_test).round(4))
knn_reg_test_gap = abs(knn_reg_score_train - knn_reg_score_test).round(4)
# Out:
# KNN Training Score: 1.0
# KNN Testing Score : 0.4041
# KNN Train-Test Gap: 0.5959

# %% [markdown]
# **Failed to meet out expectations**

# %% [markdown]
# #### Transformed Data

# %%
x_train, x_test, y_train, y_test = train_test_split(
            log_x_data, # x-variables (can change this)
            log_y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# INSTANTIATING a KNN model object
knn_reg = KNeighborsRegressor(algorithm = 'auto',
                              n_neighbors = 1)


# FITTING to the training data
knn_fit = knn_reg.fit(x_train, y_train)


# PREDICTING on new data
knn_reg_pred = knn_fit.predict(x_test)


# SCORING the results
print('KNN Training Score:', knn_reg.score(x_train, y_train).round(4))
print('KNN Testing Score :',  knn_reg.score(x_test, y_test).round(4))


# saving scoring data for future use
knn_reg_score_train = knn_reg.score(x_train, y_train).round(4)
knn_reg_score_test  = knn_reg.score(x_test, y_test).round(4)


# displaying and saving the gap between training and testing
print('KNN Train-Test Gap:', abs(knn_reg_score_train - knn_reg_score_test).round(4))
knn_reg_test_gap = abs(knn_reg_score_train - knn_reg_score_test).round(4)
# Out:
# KNN Training Score: 1.0
# KNN Testing Score : 0.1646
# KNN Train-Test Gap: 0.8354

# %% [markdown]
# **Failed to meet our requirements**

# %% [markdown]
# ### Random Forest Regression

# %% [markdown]
# #### Orginal Data

# %%
x_train, x_test, y_train, y_test = train_test_split(
            x_data, # x-variables (can change this)
            y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
from sklearn.ensemble import RandomForestRegressor
# specifying a model name
model_name = 'Random Forest'


# INSTANTIATING a random forest model with default values
model = RandomForestRegressor(n_estimators     = 100,
                                  criterion        = 'squared_error',
                                  max_depth        = 5,
                                  min_samples_leaf = 15,
                                  bootstrap        = True,
                                  warm_start       = False,
                                  random_state     = 219)


# FITTING the training data
model_fit = model.fit(x_train, y_train)


 # PREDICTING based on the testing set
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)

# Initiating dynamic Printing of results
print(f"""  
Train_Score:    {model_train_score}
Test_Score:     {model_test_score}
Train-Test Gap: {model_gap}\n\n """)
# Out:
#
# Train_Score:    0.7741
# Test_Score:     0.7209
# Train-Test Gap: 0.0532

# %% [markdown]
# **This model has also gave us good result - Accepting the model**

# %% [markdown]
# #### Transformed Data

# %%
x_train, x_test, y_train, y_test = train_test_split(
            log_x_data, # x-variables (can change this)
            log_y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)

# %%
# specifying a model name
model_name = 'Random Forest'


# INSTANTIATING a random forest model with default values
model = RandomForestRegressor(n_estimators     = 100,
                                  criterion        = 'squared_error',
                                  max_depth        = 5,
                                  min_samples_leaf = 15,
                                  bootstrap        = True,
                                  warm_start       = False,
                                  random_state     = 219)


# FITTING the training data
model_fit = model.fit(x_train, y_train)


 # PREDICTING based on the testing set
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)

# Initiating dynamic Printing of results
print(f"""
Train_Score:    {model_train_score}
Test_Score:     {model_test_score}
Train-Test Gap: {model_gap}\n\n """)
# Out:
# Train_Score:    0.8005
# Test_Score:     0.7682
# Train-Test Gap: 0.0323

# %% [markdown]
# **This model has also gave us good result - Accepting the model**

# %% [markdown]
# ______________________________________________________________________________________________________________

# %% [markdown]
# *****Linear Regression model, ARD Regression model, Ridge Regressin model, Random forest Regression model gave us our expected test, train scores and gap between the scores were also less than 0.05.
# As Random forest generation regression model with transformed data gave us good expected result. So I am choosing that model.*****

# %% [markdown]
# ________________________________________________________________________________________________________________

# %% [markdown]
# ## Final model Selection - Random Forest Regression with transformed data

# %%
model_name = 'Random Forest'
x_train, x_test, y_train, y_test = train_test_split(
            log_x_data, # x-variables (can change this)
            log_y_data, # y-variable  (can change this)
            test_size    = 0.25,
            random_state = 219)
# INSTANTIATING a random forest model with default values
model = RandomForestRegressor(n_estimators     = 100,
                                  criterion        = 'squared_error',
                                  max_depth        = 5,
                                  min_samples_leaf = 15,
                                  bootstrap        = True,
                                  warm_start       = False,
                                  random_state     = 219)


# FITTING the training data
model_fit = model.fit(x_train, y_train)


 # PREDICTING based on the testing set
model_pred = model.predict(x_test)


# SCORING the results
model_train_score = model.score(x_train, y_train).round(4) # using R-square
model_test_score  = model.score(x_test, y_test).round(4)   # using R-square
model_gap         = abs(model_train_score - model_test_score).round(4)

# Initiating dynamic Printing of results



print(f"""
\t ----------------------------------------
\t|         Final Model                    |
\t ----------------------------------------
\t |  Model Name:     {model_name}\t|
\t |  Train_Score:    {model_train_score}\t\t|
\t |  Test_Score:     {model_test_score}\t\t|
\t |  Train-Test Gap: {model_gap}\t\t|
\t ----------------------------------------
\n\n """)
# Out:
# 	 ----------------------------------------
# 	|         Final Model                    |
# 	 ----------------------------------------
# 	 |  Model Name:     Random Forest	|
# 	 |  Train_Score:    0.8005		|
# 	 |  Test_Score:     0.7682		|
# 	 |  Train-Test Gap: 0.0323		|
# 	 ----------------------------------------

# %% [markdown]
# **Random Forest Generation Regression Model With Transformmed data gave us the great expected result. i.e Training score - 0.80, test score - 0.77 and Train-Test Gap which is equal to 0.0323.**
